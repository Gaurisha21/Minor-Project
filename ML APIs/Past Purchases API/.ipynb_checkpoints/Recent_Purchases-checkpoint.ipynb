# %% [markdown]
# # Deliverable 1: Point 1

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori
from mlxtend.frequent_patterns import association_rules
import collections

# %% [markdown]
# ## The Dataset contains the purchase history of a user

# %%
purchases = pd.read_csv('Book1.csv', header = None)
purchases.head()
# Out:
#                 0              1          2           3                 4   \
# 0  roasted almonds         shrimp    almonds     avocado    vegetables mix
# 1  fried meatballs        burgers  meatballs        eggs               NaN
# 2    cloth napkins        chutney        NaN         NaN               NaN
# 3    baked chicken         turkey    avocado         NaN               NaN
# 4   tomatoes puree  mineral water       milk  energy bar  whole wheat rice
#
#              5                 6     7               8             9   ...  \
# 0  green grapes  whole weat flour  yams  cottage cheese  energy drink  ...
# 1           NaN               NaN   NaN             NaN           NaN  ...
# 2           NaN               NaN   NaN             NaN           NaN  ...
# 3           NaN               NaN   NaN             NaN           NaN  ...
# 4     green tea               NaN   NaN             NaN           NaN  ...
#
#                11         12     13     14             15      16  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   17               18       19         20
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Converting to list

# %%
purchases.values.tolist()
# Out:
# [['roasted almonds',
#   'shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['fried meatballs',
#   'burgers',
#   'meatballs',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cloth napkins',
#   'chutney',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked chicken',
#   'turkey',
#   'avocado',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomatoes puree',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked vegetables',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged red wine',
#   'whole wheat pasta',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['barbecue powder',
#   'soup',
#   'light cream',
#   'shallot',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Parmigiano Reggiano',
#   'frozen vegetables',
#   'spaghetti',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Parmigiano Reggiano',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smoothie',
#   'eggs',
#   'pet food',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sliced fromage blanc ',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lavender body spray',
#   'turkey',
#   'burgers',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['protein bar',
#   'spaghetti',
#   'champagne',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['gluten free chocolate bar',
#   'mineral water',
#   'salmon',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['bramble',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged champagne',
#   'shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked spaghetti',
#   'turkey',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multi-grain bread',
#   'turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['orange soda',
#   'meatballs',
#   'milk',
#   'honey',
#   'french fries',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'red wine',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'eggs',
#   'chocolate',
#   'shampoo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry babies food',
#   'rice',
#   'sparkling water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen salad',
#   'spaghetti',
#   'mineral water',
#   'ham',
#   'body spray',
#   'pancakes',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked chicken',
#   'burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark chocolate',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby carrots ',
#   'parmesan cheese',
#   'spaghetti',
#   'soup',
#   'avocado',
#   'milk',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry babies food',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cheese sandwich',
#   'sparkling water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['bramble',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'chocolate',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['browny fudge ',
#   'frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'herb & pepper',
#   'tomato sauce',
#   'light cream',
#   'magazines',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen yogurt',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat spagetti',
#   'turkey',
#   'french fries',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen yogurt',
#   'frozen vegetables',
#   'strong cheese',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multi-purpose essentials',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry sparkling water',
#   'pickles',
#   'spaghetti',
#   'salmon',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['toned milk',
#   'energy bar',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['potato chips',
#   'red wine',
#   'ground beef',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked vegetables',
#   'mineral water',
#   'cake',
#   'cottage cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multigrained flour',
#   'pickles',
#   'champagne',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cheese sandwich',
#   'spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multi-grain bread',
#   'fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh chopped tuna',
#   'spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['protein bar',
#   'soup',
#   'meatballs',
#   'hot dogs',
#   'sparkling water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['black beauty zucchini',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['green chili',
#   'mineral water',
#   'chicken',
#   'cereals',
#   'clothes accessories',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mango cream',
#   'mineral water',
#   'bug spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lavender body spray',
#   'avocado',
#   'muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'burgers',
#   'black tea',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lawn bug spray',
#   'spaghetti',
#   'chocolate',
#   'brownies',
#   'white wine',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cream sauce',
#   'fresh tuna',
#   'mineral water',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked turkey',
#   'spaghetti',
#   'muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['glucose energy bar',
#   'spaghetti',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mint powder',
#   'french fries',
#   'escalope',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['coconut oil',
#   'tomato sauce',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pudina chutney',
#   'turkey',
#   'fresh tuna',
#   'frozen vegetables',
#   'tomatoes',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['toned milk',
#   'eggs',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['brown rice',
#   'soup',
#   'chicken',
#   'gums',
#   'soda',
#   'body spray',
#   'energy drink',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sweet corn soup',
#   'turkey',
#   'frozen vegetables',
#   'mineral water',
#   'cider',
#   'cooking oil',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['peri peri french fries',
#   'spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby carrots ',
#   'clothes accessories',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby corn',
#   'energy drink',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['bubble gums',
#   'soup',
#   'bug spray',
#   'shallot',
#   'protein bar',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark chocolate',
#   'turkey',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged red wine',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted toothpaste',
#   'chocolate',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark chocolate',
#   'herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'cider',
#   'whole wheat rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fat milk',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby carrots ',
#   'shrimp',
#   'pasta',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato ketch up',
#   'grated cheese',
#   'herb & pepper',
#   'tomatoes',
#   'tomato sauce',
#   'corn',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged champagne',
#   'burgers',
#   'escalope',
#   'shallot',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat spagetti',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['flax seed powder',
#   'yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mango cream',
#   'soup',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sliced cheese',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cream sauce',
#   'mineral water',
#   'chocolate',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['assamese tea',
#   'eggs',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['apple cider',
#   'grated cheese',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'white wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['gluten free chocolate bar',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked asparagus',
#   'eggs',
#   'cake',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['protein fat bar',
#   'burgers',
#   'spaghetti',
#   'milk',
#   'french fries',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['potato chips',
#   'mineral water',
#   'energy bar',
#   'butter',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mint powder',
#   'burgers',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['oat pasta',
#   'energy bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['water',
#   'energy bar',
#   'energy drink',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chopped cauliflower',
#   'chocolate',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato chutney',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked salmon',
#   'asparagus',
#   'salad',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fried bacon',
#   'burgers',
#   'french fries',
#   'low fat yogurt',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smelly cheese',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['assamese tea',
#   'burgers',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'energy bar',
#   'french wine',
#   'eggs',
#   'salt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Parmigiano Reggiano',
#   'champagne',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['protein fat bar',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen salad',
#   'burgers',
#   'almonds',
#   'eggs',
#   'french fries',
#   'cookies',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby eggplant',
#   'ham',
#   'soup',
#   'escalope',
#   'body spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby carrots ',
#   'turkey',
#   'ham',
#   'frozen vegetables',
#   'pepper',
#   'oil',
#   'extra dark chocolate',
#   'tea',
#   'magazines',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['coconut oil',
#   'muffins',
#   'eggs',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['black beauty zucchini',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato chutney',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smelly cheese',
#   'mineral water',
#   'barbecue sauce',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['canola olive oil',
#   'burgers',
#   'herb & pepper',
#   'energy bar',
#   'almonds',
#   'eggs',
#   'corn',
#   'mayonnaise',
#   'zucchini',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['flavored mayo',
#   'turkey',
#   'burgers',
#   'ground beef',
#   'chocolate',
#   'soup',
#   'almonds',
#   'eggs',
#   'hot dogs',
#   'cottage cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whipped cream',
#   'ham',
#   'spaghetti',
#   'chocolate',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multigrained flour',
#   'ground beef',
#   'energy bar',
#   'pet food',
#   'carrots',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked ham',
#   'ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['rock salt',
#   'mineral water',
#   'olive oil',
#   'gums',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark forest cake',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'soup',
#   'avocado',
#   'milk',
#   'olive oil',
#   'green grapes',
#   'eggs',
#   'bug spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat spagetti',
#   'shrimp',
#   'pasta',
#   'soup',
#   'cake',
#   'cooking oil',
#   'chicken',
#   'light mayo',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['flax seed powder',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'escalope',
#   'mushroom cream sauce',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat spagetti',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked asparagus',
#   'burgers',
#   'oil',
#   'tomato juice',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pink shallot',
#   'french wine',
#   'eggs',
#   'chocolate',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby carrots ',
#   'chicken',
#   'eggs',
#   'french fries',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry sparkling water',
#   'turkey',
#   'herb & pepper',
#   'salmon',
#   'white wine',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['honey lemon green tea',
#   'grated cheese',
#   'spaghetti',
#   'olive oil',
#   'eggs',
#   'french fries',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomatoes puree',
#   'mineral water',
#   'energy bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato ketch up',
#   'eggs',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['peri peri french fries',
#   'burgers',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'chocolate',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['browny fudge ',
#   'muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mexican avocado',
#   'pasta',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['white chocolate',
#   'tomatoes',
#   'spaghetti',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['bubble gums',
#   'ground beef',
#   'spaghetti',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted butter',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['vanila cake',
#   'chocolate',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['honey lemon green tea',
#   'burgers',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked ham',
#   'ground beef',
#   'mineral water',
#   'antioxydant juice',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['african yams',
#   'grated cheese',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'cake',
#   'energy drink',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chewy candy bars',
#   'grated cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mexican avocado',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['black beauty zucchini',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mexican avocado',
#   'carrots',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['bramble',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dry spinach',
#   'turkey',
#   'burgers',
#   'chocolate',
#   'olive oil',
#   'eggs',
#   'cooking oil',
#   'corn',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['water',
#   'frozen vegetables',
#   'tomatoes',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'pancakes',
#   'chicken',
#   'chili',
#   'tea',
#   'french fries',
#   'tomato juice',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chewy candy bars',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['veg burgers',
#   'ground beef',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['water spray jet',
#   'turkey',
#   'eggs',
#   'chocolate',
#   'frozen smoothie',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat spagetti',
#   'frozen vegetables',
#   'cooking oil',
#   'mashed potato',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'light cream',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mango pickles',
#   'red wine',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'cake',
#   'gums',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato ketch up',
#   'chocolate',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'eggs',
#   'rice',
#   'french fries',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted ground beef',
#   'chocolate',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['flax seed powder',
#   'turkey',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomatoes puree',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['beans',
#   'turkey',
#   'tomatoes',
#   'cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'yams',
#   'mineral water',
#   'soup',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'barbecue sauce',
#   'carrots',
#   'chocolate',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['orange soda',
#   'rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['basmati rice',
#   'chocolate',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen yogurt',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'water spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato soup',
#   'burgers',
#   'mineral water',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['canola olive oil',
#   'mineral water',
#   'vegetables mix',
#   'cake',
#   'frozen smoothie',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sweet corn soup',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked escalope',
#   'shrimp',
#   'pasta',
#   'chicken',
#   'chocolate bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked turkey',
#   'shallot',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sweet corn soup',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'eggs',
#   'hot dogs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pink shallot',
#   'burgers',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pudina chutney',
#   'red wine',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'strong cheese',
#   'light cream',
#   'cooking oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lemon black tea',
#   'burgers',
#   'grated cheese',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'oil',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby corn',
#   'herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['water spray jet',
#   'shrimp',
#   'pasta',
#   'yams',
#   'milk',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smelly cheese',
#   'butter',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked ham',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['toned milk',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pudina chutney',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked salmon',
#   'burgers',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cheddar cheese',
#   'turkey',
#   'herb & pepper',
#   'ground beef',
#   'soup',
#   'avocado',
#   'milk',
#   'black tea',
#   'eggs',
#   'barbecue sauce',
#   'carrots',
#   'cookies',
#   'tomato juice',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen salad',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Parmigiano Reggiano',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['assamese tea',
#   'pepper',
#   'french fries',
#   'strawberries',
#   'pancakes',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['oat pasta',
#   'frozen vegetables',
#   'yams',
#   'chicken',
#   'honey',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['african yams',
#   'chocolate',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby corn',
#   'herb & pepper',
#   'honey',
#   'cake',
#   'rice',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grape wine',
#   'burgers',
#   'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'light mayo',
#   'asparagus',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fresh chopped tuna',
#   'chocolate',
#   'mineral water',
#   'corn',
#   'cottage cheese',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['rock salt',
#   'muffins',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat spagetti',
#   'ham',
#   'french wine',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['masala oatmeal',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'mint green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['seasoned herb & pepper',
#   'chocolate',
#   'body spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['assamese tea',
#   'frozen vegetables',
#   'french fries',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cream sauce',
#   'burgers',
#   'shrimp',
#   'pasta',
#   'milk',
#   'green tea',
#   'french fries',
#   'cookies',
#   'white wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted ground beef',
#   'parmesan cheese',
#   'ground beef',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato chutney',
#   'pancakes',
#   'whole wheat rice',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['boiled eggs',
#   'eggs',
#   'eggplant',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark chocolate',
#   'frozen vegetables',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['glucose energy drink',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['boiled eggs',
#   'turkey',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged white wine',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'soup',
#   'meatballs',
#   'chicken',
#   'blueberries',
#   'cooking oil',
#   'champagne',
#   'yogurt cake',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['oat pasta',
#   'cooking oil',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fat milk',
#   'frozen vegetables',
#   'milk',
#   'eggs',
#   'french fries',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['potato chips',
#   'fresh tuna',
#   'spaghetti',
#   'olive oil',
#   'french wine',
#   'eggs',
#   'french fries',
#   'champagne',
#   'pancakes',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['toned milk',
#   'red wine',
#   'honey',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smelly cheese',
#   'milk',
#   'bacon',
#   'eggs',
#   'french fries',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cheddar cheese',
#   'french fries',
#   'yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby corn',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cheddar cheese',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mayonnaise dip',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burger mayo',
#   'burgers',
#   'ham',
#   'red wine',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['purple grapes',
#   'shrimp',
#   'pasta',
#   'tomatoes',
#   'energy bar',
#   'french wine',
#   'antioxydant juice',
#   'french fries',
#   'frozen smoothie',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato chutney',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['barbecue powder',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['choco chip muffins',
#   'turkey',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'spinach',
#   'soda',
#   'energy drink',
#   'salt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['masala oatmeal',
#   'turkey',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen salad',
#   'bug spray',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozon vegetables mix',
#   'oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby corn',
#   'soup',
#   'energy bar',
#   'chicken',
#   'eggs',
#   'cake',
#   'french fries',
#   'body spray',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smoothie',
#   'spaghetti',
#   'chocolate',
#   'yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mint powder',
#   'turkey',
#   'mineral water',
#   'meatballs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark forest cake',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'fromage blanc',
#   'bacon',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dry spinach',
#   'frozen vegetables',
#   'mineral water',
#   'vegetables mix',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato chutney',
#   'herb & pepper',
#   'red wine',
#   'tomatoes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted shrimp',
#   'whole wheat pasta',
#   'olive oil',
#   'cereals',
#   'brownies',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multi-purpose essentials',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chopped cauliflower',
#   'olive oil',
#   'cookies',
#   'mushroom cream sauce',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mango pickles',
#   'ground beef',
#   'pancakes',
#   'cooking oil',
#   'gluten free bar',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'mineral water',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['orange soda',
#   'herb & pepper',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['bubble gums',
#   'salmon',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark chocolate',
#   'eggs',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomatoes puree',
#   'mineral water',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['toned milk',
#   'mineral water',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['oat cereals',
#   'shrimp',
#   'mineral water',
#   'soup',
#   'black tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked asparagus',
#   'cake',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['golden honey',
#   'turkey',
#   'burgers',
#   'grated cheese',
#   'tomatoes',
#   'chocolate',
#   'fromage blanc',
#   'honey',
#   'whole wheat rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['flavored mayo',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['golden honey',
#   'turkey',
#   'burgers',
#   'ground beef',
#   'milk',
#   'olive oil',
#   'cake',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['grape wine',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'soup',
#   'chutney',
#   'cereals',
#   'energy drink',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cheese sandwich',
#   'eggs',
#   'whole wheat rice',
#   'cake',
#   'green tea',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['french red wine',
#   'ground beef',
#   'yams',
#   'soup',
#   'avocado',
#   'salmon',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pepper powder ',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry sparkling water',
#   'spaghetti',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['blue berry',
#   'whole wheat pasta',
#   'honey',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smoothie',
#   'whole wheat pasta',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['flavored mayo',
#   'spaghetti',
#   'meatballs',
#   'vegetables mix',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sliced cheese',
#   'eggs',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged red wine',
#   'fresh tuna',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'olive oil',
#   'eggs',
#   'cake',
#   'brownies',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['water spray jet',
#   'mineral water',
#   'green grapes',
#   'hot dogs',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted toothpaste',
#   'frozen vegetables',
#   'meatballs',
#   'eggs',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted shrimp',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lavender body spray',
#   'meatballs',
#   'milk',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked chicken',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby carrots ',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['peri peri french fries',
#   'escalope',
#   'pasta',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['white strawberries',
#   'pepper',
#   'chocolate',
#   'olive oil',
#   'french wine',
#   'salmon',
#   'rice',
#   'light mayo',
#   'fresh bread',
#   'magazines',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['roasted almonds',
#   'red wine',
#   'french wine',
#   'vegetables mix',
#   'rice',
#   'clothes accessories',
#   'hot dogs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['glucose energy drink',
#   'burgers',
#   'dessert wine',
#   'spaghetti',
#   'chicken',
#   'cake',
#   'protein bar',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multigrained flour',
#   'french wine',
#   'cake',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['peri peri french fries',
#   'burgers',
#   'frozen vegetables',
#   'flax seed',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['blue berry',
# ...
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted shrimp',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['Parmigiano Reggiano',
#   'whole wheat rice',
#   'oil',
#   'chicken',
#   'french fries',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked turkey',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato chutney',
#   'parmesan cheese',
#   'whole wheat rice',
#   'escalope',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['water spray jet',
#   'fresh tuna',
#   'frozen vegetables',
#   'chicken',
#   'fromage blanc',
#   'honey',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked chicken',
#   'ground beef',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lavender body spray',
#   'muffins',
#   'champagne',
#   'cookies',
#   'fresh bread',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mayonnaise dip',
#   'frozen vegetables',
#   'spaghetti',
#   'chocolate',
#   'escalope',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['boiled eggs',
#   'pickles',
#   'spaghetti',
#   'french fries',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['boiled eggs',
#   'avocado',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked vegetables',
#   'sandwich',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry sparkling water',
#   'spaghetti',
#   'milk',
#   'oil',
#   'shampoo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted toothpaste',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozon vegetables mix',
#   'spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted ground beef',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pink shallot',
#   'avocado',
#   'milk',
#   'butter',
#   'french fries',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen yogurt',
#   'turkey',
#   'frozen vegetables',
#   'chicken',
#   'eggs',
#   'frozen smoothie',
#   'cauliflower',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['masala oatmeal',
#   'burgers',
#   'shrimp',
#   'tomatoes',
#   'milk',
#   'energy bar',
#   'almonds',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'body spray',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged white wine',
#   'burgers',
#   'milk',
#   'cake',
#   'cooking oil',
#   'french fries',
#   'escalope',
#   'zucchini',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['choco chip cookies',
#   'tomatoes',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'frozen smoothie',
#   'protein bar',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['peri peri french fries',
#   'fresh tuna',
#   'red wine',
#   'pepper',
#   'spaghetti',
#   'fromage blanc',
#   'salmon',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked spaghetti',
#   'milk',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby corn',
#   'shrimp',
#   'parmesan cheese',
#   'soup',
#   'chocolate',
#   'brownies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['protein bar',
#   'spaghetti',
#   'chicken',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['oat pasta',
#   'grated cheese',
#   'vegetables mix',
#   'nonfat milk',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baked salmon',
#   'fresh tuna',
#   'parmesan cheese',
#   'cider',
#   'muffins',
#   'spinach',
#   'honey',
#   'oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['aged champagne',
#   'cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['white chocolate',
#   'shrimp',
#   'chocolate',
#   'mushroom cream sauce',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted butter',
#   'candy bars',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked ham',
#   'avocado',
#   'honey',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dog pet food',
#   'shrimp',
#   'frozen vegetables',
#   'tomatoes',
#   'cottage cheese',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted shrimp',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['mustard hot dogs',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['burger mayo',
#   'ground beef',
#   'almonds',
#   'french fries',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sliced fromage blanc ',
#   'grated cheese',
#   'spaghetti',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whole wheat spagetti',
#   'turkey',
#   'mineral water',
#   'butter',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['cooked spaghetti',
#   'frozen vegetables',
#   'spaghetti',
#   'french fries',
#   'light mayo',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['orange soda',
#   'burgers',
#   'ham',
#   'spaghetti',
#   'whole wheat rice',
#   'eggplant',
#   'chocolate',
#   'cookies',
#   'shallot',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['purple grapes',
#   'grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'blueberries',
#   'light cream',
#   'rice',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'hot dogs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['african yams',
#   'burgers',
#   'shrimp',
#   'tomatoes',
#   'bacon',
#   'whole wheat rice',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['blue berry',
#   'parmesan cheese',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted toothpaste',
#   'parmesan cheese',
#   'cake',
#   'hot dogs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['peri peri french fries',
#   'spaghetti',
#   'milk',
#   'fromage blanc',
#   'ketchup',
#   'chocolate',
#   'babies food',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['green chili',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['baby eggplant',
#   'chocolate',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['fried bacon',
#   'butter',
#   'french fries',
#   'salt',
#   'fresh bread',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['white strawberries',
#   'chocolate',
#   'french fries',
#   'strawberries',
#   'yogurt cake',
#   'light mayo',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['protein bar',
#   'eggs',
#   'eggplant',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pudina chutney',
#   'yogurt cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato soup',
#   'herb & pepper',
#   'spaghetti',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'honey',
#   'frozen smoothie',
#   'escalope',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen yogurt',
#   'frozen vegetables',
#   'rice',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry babies food',
#   'herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'eggs',
#   'light cream',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato soup',
#   'eggs',
#   'champagne',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['flavored mayo',
#   'whole wheat pasta',
#   'ground beef',
#   'olive oil',
#   'blueberries',
#   'escalope',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['white strawberries',
#   'burgers',
#   'red wine',
#   'mineral water',
#   'eggs',
#   'oil',
#   'carrots',
#   'hand protein bar',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lemon black tea',
#   'chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'soup',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['lemon black tea',
#   'burgers',
#   'shrimp',
#   'mineral water',
#   'chicken',
#   'fromage blanc',
#   'salmon',
#   'eggs',
#   'cake',
#   'frozen smoothie',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['salted ground beef',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['water',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['black beauty zucchini',
#   'french fries',
#   'cookies',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['tomato soup',
#   'milk',
#   'butter',
#   'eggs',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['strawberry babies food',
#   'eggs',
#   'mushroom cream sauce',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['black beauty zucchini',
#   'eggs',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['multi-purpose essentials',
#   'mineral water',
#   'whole wheat rice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['glucose energy drink',
#   'shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'mineral water',
#   'whole wheat rice',
#   'cake',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['dark chocolate',
#   'whole wheat rice',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['whipped cream',
#   'frozen vegetables',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'salmon',
#   'oil',
#   'cooking oil',
#   'frozen smoothie',
#   'cauliflower',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pepper powder ',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['pink shallot',
#   'fresh tuna',
#   'eggs',
#   'escalope',
#   'strawberries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['sliced fromage blanc ',
#   'spaghetti',
#   'soup',
#   'milk',
#   'carrots',
#   'chocolate',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['smelly cheese',
#   'burgers',
#   'mineral water',
#   'soup',
#   'meatballs',
#   'olive oil',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen yogurt',
#   'grated cheese',
#   'mineral water',
#   'cooking oil',
#   'french fries',
#   'cookies',
#   'low fat yogurt',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['chewy candy bars',
#   'shrimp',
#   'milk',
#   'olive oil',
#   'french fries',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['blue berry',
#   'frozen vegetables',
#   'mineral water',
#   'pancakes',
#   'cake',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozon vegetables mix',
#   'spaghetti',
#   'milk',
#   'chicken',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['white chocolate',
#   'grated cheese',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'cottage cheese',
#   'pancakes',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['frozen salad',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'eggs',
#   'mint',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['antioxydant sour juice',
#   'shrimp',
#   'body spray',
#   'green tea',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['oat cereals',
#   'frozen smoothie',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['veg burgers',
#   'herb & pepper',
#   'frozen vegetables',
#   'mineral water',
#   'muffins',
#   'cereals',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['choco chip muffins',
#   'turkey',
#   'tomatoes',
#   'spaghetti',
#   'milk',
#   'cider',
#   'eggs',
#   'honey',
#   'cake',
#   'green tea',
#   'french fries',
#   'brownies',
#   'tomato juice',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ...]

# %% [markdown]
# ### Removing the 'nan'

# %%
purchaseList = []
for i in range(len(purchases)):
    purchaseList.append([str(purchases.values[i,j]) for j in range(0, 20) if str(purchases.values[i,j])!='nan'])
purchaseList
# Out:
# [['roasted almonds',
#   'shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach'],
#  ['fried meatballs', 'burgers', 'meatballs', 'eggs'],
#  ['cloth napkins', 'chutney'],
#  ['baked chicken', 'turkey', 'avocado'],
#  ['tomatoes puree',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'whole wheat rice',
#   'green tea'],
#  ['baked vegetables', 'low fat yogurt'],
#  ['aged red wine', 'whole wheat pasta', 'french fries'],
#  ['barbecue powder', 'soup', 'light cream', 'shallot'],
#  ['Parmigiano Reggiano', 'frozen vegetables', 'spaghetti', 'green tea'],
#  ['Parmigiano Reggiano', 'french fries'],
#  ['smoothie', 'eggs', 'pet food'],
#  ['sliced fromage blanc ', 'cookies'],
#  ['lavender body spray',
#   'turkey',
#   'burgers',
#   'mineral water',
#   'eggs',
#   'cooking oil'],
#  ['protein bar', 'spaghetti', 'champagne', 'cookies'],
#  ['gluten free chocolate bar', 'mineral water', 'salmon'],
#  ['bramble', 'mineral water'],
#  ['aged champagne',
#   'shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt'],
#  ['cooked spaghetti', 'turkey', 'eggs'],
#  ['multi-grain bread',
#   'turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate'],
#  ['orange soda', 'meatballs', 'milk', 'honey', 'french fries', 'protein bar'],
#  ['antioxydant sour juice',
#   'red wine',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'eggs',
#   'chocolate',
#   'shampoo'],
#  ['strawberry babies food', 'rice', 'sparkling water'],
#  ['frozen salad',
#   'spaghetti',
#   'mineral water',
#   'ham',
#   'body spray',
#   'pancakes',
#   'green tea'],
#  ['baked chicken',
#   'burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste'],
#  ['dark chocolate', 'eggs'],
#  ['baby carrots ',
#   'parmesan cheese',
#   'spaghetti',
#   'soup',
#   'avocado',
#   'milk',
#   'fresh bread'],
#  ['strawberry babies food',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope'],
#  ['cheese sandwich', 'sparkling water'],
#  ['bramble', 'mineral water', 'eggs', 'chicken', 'chocolate', 'french fries'],
#  ['browny fudge ', 'frozen vegetables', 'spaghetti', 'yams', 'mineral water'],
#  ['antioxydant sour juice',
#   'herb & pepper',
#   'tomato sauce',
#   'light cream',
#   'magazines'],
#  ['frozen yogurt', 'mineral water', 'chocolate', 'avocado', 'eggs'],
#  ['whole wheat spagetti', 'turkey', 'french fries', 'strawberries'],
#  ['frozen yogurt', 'frozen vegetables', 'strong cheese', 'chocolate'],
#  ['multi-purpose essentials', 'cookies'],
#  ['strawberry sparkling water', 'pickles', 'spaghetti', 'salmon', 'escalope'],
#  ['toned milk', 'energy bar', 'french fries'],
#  ['potato chips', 'red wine', 'ground beef', 'mineral water'],
#  ['baked vegetables', 'mineral water', 'cake', 'cottage cheese'],
#  ['multigrained flour', 'pickles', 'champagne', 'green tea'],
#  ['cheese sandwich', 'spaghetti'],
#  ['multi-grain bread',
#   'fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope'],
#  ['fresh chopped tuna', 'spaghetti'],
#  ['protein bar', 'soup', 'meatballs', 'hot dogs', 'sparkling water'],
#  ['black beauty zucchini', 'escalope'],
#  ['antioxydant sour juice',
#   'soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea'],
#  ['green chili', 'mineral water', 'chicken', 'cereals', 'clothes accessories'],
#  ['mango cream', 'mineral water', 'bug spray'],
#  ['lavender body spray', 'avocado', 'muffins'],
#  ['antioxydant sour juice', 'burgers', 'black tea', 'green tea'],
#  ['lawn bug spray',
#   'spaghetti',
#   'chocolate',
#   'brownies',
#   'white wine',
#   'green tea'],
#  ['cream sauce', 'fresh tuna', 'mineral water', 'eggs'],
#  ['baked turkey', 'spaghetti', 'muffins'],
#  ['glucose energy bar', 'spaghetti', 'chocolate'],
#  ['mint powder', 'french fries', 'escalope', 'champagne'],
#  ['coconut oil', 'tomato sauce', 'light mayo'],
#  ['pudina chutney',
#   'turkey',
#   'fresh tuna',
#   'frozen vegetables',
#   'tomatoes',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil'],
#  ['toned milk', 'eggs', 'cookies'],
#  ['brown rice',
#   'soup',
#   'chicken',
#   'gums',
#   'soda',
#   'body spray',
#   'energy drink',
#   'green tea'],
#  ['sweet corn soup',
#   'turkey',
#   'frozen vegetables',
#   'mineral water',
#   'cider',
#   'cooking oil',
#   'green tea'],
#  ['peri peri french fries', 'spaghetti'],
#  ['baby carrots ', 'clothes accessories'],
#  ['baby corn', 'energy drink'],
#  ['bubble gums', 'soup', 'bug spray', 'shallot', 'protein bar', 'green tea'],
#  ['dark chocolate', 'turkey', 'eggs'],
#  ['aged red wine', 'french fries'],
#  ['salted toothpaste', 'chocolate', 'milk'],
#  ['dark chocolate',
#   'herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'cider',
#   'whole wheat rice'],
#  ['fat milk', 'cookies'],
#  ['baby carrots ', 'shrimp', 'pasta'],
#  ['tomato ketch up',
#   'grated cheese',
#   'herb & pepper',
#   'tomatoes',
#   'tomato sauce',
#   'corn'],
#  ['aged champagne', 'burgers', 'escalope', 'shallot'],
#  ['whole wheat spagetti', 'cookies'],
#  ['flax seed powder', 'yogurt cake'],
#  ['mango cream', 'soup', 'eggs'],
#  ['sliced cheese', 'cookies'],
#  ['cream sauce', 'mineral water', 'chocolate', 'low fat yogurt'],
#  ['assamese tea', 'eggs', 'strawberries'],
#  ['apple cider',
#   'grated cheese',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'white wine'],
#  ['gluten free chocolate bar', 'mint'],
#  ['baked asparagus', 'eggs', 'cake', 'french fries'],
#  ['protein fat bar',
#   'burgers',
#   'spaghetti',
#   'milk',
#   'french fries',
#   'green tea'],
#  ['potato chips', 'mineral water', 'energy bar', 'butter', 'french fries'],
#  ['mint powder',
#   'burgers',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'eggs',
#   'cooking oil'],
#  ['oat pasta', 'energy bar'],
#  ['water', 'energy bar', 'energy drink'],
#  ['chopped cauliflower', 'chocolate', 'frozen smoothie'],
#  ['tomato chutney', 'low fat yogurt'],
#  ['baked salmon', 'asparagus', 'salad'],
#  ['fried bacon', 'burgers', 'french fries', 'low fat yogurt', 'green tea'],
#  ['smelly cheese', 'low fat yogurt'],
#  ['assamese tea',
#   'burgers',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'energy bar',
#   'french wine',
#   'eggs',
#   'salt'],
#  ['Parmigiano Reggiano', 'champagne', 'low fat yogurt'],
#  ['protein fat bar', 'champagne'],
#  ['frozen salad',
#   'burgers',
#   'almonds',
#   'eggs',
#   'french fries',
#   'cookies',
#   'green tea'],
#  ['baby eggplant', 'ham', 'soup', 'escalope', 'body spray'],
#  ['baby carrots ',
#   'turkey',
#   'ham',
#   'frozen vegetables',
#   'pepper',
#   'oil',
#   'extra dark chocolate',
#   'tea',
#   'magazines'],
#  ['coconut oil', 'muffins', 'eggs', 'cookies'],
#  ['black beauty zucchini', 'cookies'],
#  ['tomato chutney',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'green tea'],
#  ['smelly cheese', 'mineral water', 'barbecue sauce', 'chocolate'],
#  ['canola olive oil',
#   'burgers',
#   'herb & pepper',
#   'energy bar',
#   'almonds',
#   'eggs',
#   'corn',
#   'mayonnaise',
#   'zucchini'],
#  ['flavored mayo',
#   'turkey',
#   'burgers',
#   'ground beef',
#   'chocolate',
#   'soup',
#   'almonds',
#   'eggs',
#   'hot dogs',
#   'cottage cheese'],
#  ['whipped cream', 'ham', 'spaghetti', 'chocolate', 'eggs'],
#  ['multigrained flour',
#   'ground beef',
#   'energy bar',
#   'pet food',
#   'carrots',
#   'protein bar'],
#  ['cooked ham',
#   'ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'eggs'],
#  ['rock salt', 'mineral water', 'olive oil', 'gums', 'cooking oil'],
#  ['dark forest cake',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'soup',
#   'avocado',
#   'milk',
#   'olive oil',
#   'green grapes',
#   'eggs',
#   'bug spray'],
#  ['whole wheat spagetti',
#   'shrimp',
#   'pasta',
#   'soup',
#   'cake',
#   'cooking oil',
#   'chicken',
#   'light mayo',
#   'low fat yogurt'],
#  ['flax seed powder',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'escalope',
#   'mushroom cream sauce',
#   'fresh bread'],
#  ['whole wheat spagetti', 'shrimp', 'pasta', 'mineral water', 'eggs'],
#  ['baked asparagus', 'burgers', 'oil', 'tomato juice', 'fresh bread'],
#  ['pink shallot', 'french wine', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['baby carrots ', 'chicken', 'eggs', 'french fries', 'pancakes'],
#  ['strawberry sparkling water',
#   'turkey',
#   'herb & pepper',
#   'salmon',
#   'white wine',
#   'candy bars'],
#  ['honey lemon green tea',
#   'grated cheese',
#   'spaghetti',
#   'olive oil',
#   'eggs',
#   'french fries',
#   'green tea'],
#  ['tomatoes puree', 'mineral water', 'energy bar'],
#  ['tomato ketch up', 'eggs', 'french fries'],
#  ['peri peri french fries',
#   'burgers',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'chocolate',
#   'tomato juice'],
#  ['browny fudge ', 'muffins'],
#  ['mexican avocado', 'pasta'],
#  ['white chocolate', 'tomatoes', 'spaghetti', 'frozen smoothie'],
#  ['bubble gums', 'ground beef', 'spaghetti', 'milk'],
#  ['salted butter', 'french fries'],
#  ['vanila cake', 'chocolate', 'milk'],
#  ['honey lemon green tea',
#   'burgers',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'low fat yogurt'],
#  ['cooked ham',
#   'ground beef',
#   'mineral water',
#   'antioxydant juice',
#   'protein bar'],
#  ['african yams',
#   'grated cheese',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'cake',
#   'energy drink'],
#  ['chewy candy bars', 'grated cheese'],
#  ['mexican avocado', 'pancakes'],
#  ['black beauty zucchini', 'frozen smoothie'],
#  ['mexican avocado', 'carrots', 'green tea'],
#  ['bramble', 'chocolate'],
#  ['dry spinach',
#   'turkey',
#   'burgers',
#   'chocolate',
#   'olive oil',
#   'eggs',
#   'cooking oil',
#   'corn'],
#  ['water',
#   'frozen vegetables',
#   'tomatoes',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'pancakes',
#   'chicken',
#   'chili',
#   'tea',
#   'french fries',
#   'tomato juice',
#   'fresh bread'],
#  ['chewy candy bars', 'cookies'],
#  ['veg burgers', 'ground beef'],
#  ['water spray jet',
#   'turkey',
#   'eggs',
#   'chocolate',
#   'frozen smoothie',
#   'tomato juice'],
#  ['whole wheat spagetti', 'frozen vegetables', 'cooking oil', 'mashed potato'],
#  ['dark chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'light cream',
#   'tomato juice'],
#  ['mango pickles',
#   'red wine',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'cake',
#   'gums',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie'],
#  ['tomato ketch up',
#   'chocolate',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'eggs',
#   'rice',
#   'french fries',
#   'brownies'],
#  ['salted ground beef',
#   'chocolate',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'eggs'],
#  ['flax seed powder',
#   'turkey',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'french fries'],
#  ['tomatoes puree', 'cookies'],
#  ['beans', 'turkey', 'tomatoes', 'cake'],
#  ['antioxydant sour juice',
#   'yams',
#   'mineral water',
#   'soup',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'barbecue sauce',
#   'carrots',
#   'chocolate',
#   'champagne'],
#  ['orange soda', 'rice'],
#  ['basmati rice', 'chocolate', 'milk'],
#  ['frozen yogurt', 'shrimp', 'pasta', 'frozen vegetables', 'water spray'],
#  ['tomato soup',
#   'burgers',
#   'mineral water',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'mint'],
#  ['canola olive oil',
#   'mineral water',
#   'vegetables mix',
#   'cake',
#   'frozen smoothie',
#   'brownies'],
#  ['sweet corn soup', 'cookies'],
#  ['cooked escalope', 'shrimp', 'pasta', 'chicken', 'chocolate bread'],
#  ['baked turkey', 'shallot'],
#  ['sweet corn soup',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'eggs',
#   'hot dogs',
#   'green tea'],
#  ['pink shallot', 'burgers'],
#  ['pudina chutney',
#   'red wine',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'strong cheese',
#   'light cream',
#   'cooking oil'],
#  ['lemon black tea',
#   'burgers',
#   'grated cheese',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'oil',
#   'french fries'],
#  ['baby corn',
#   'herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil'],
#  ['water spray jet', 'shrimp', 'pasta', 'yams', 'milk', 'chocolate'],
#  ['smelly cheese', 'butter', 'green tea'],
#  ['cooked ham', 'light mayo'],
#  ['toned milk', 'low fat yogurt'],
#  ['pudina chutney', 'herb & pepper', 'shrimp', 'pasta', 'spaghetti', 'milk'],
#  ['baked salmon', 'burgers', 'eggs'],
#  ['cheddar cheese',
#   'turkey',
#   'herb & pepper',
#   'ground beef',
#   'soup',
#   'avocado',
#   'milk',
#   'black tea',
#   'eggs',
#   'barbecue sauce',
#   'carrots',
#   'cookies',
#   'tomato juice',
#   'fresh bread'],
#  ['frozen salad', 'cookies'],
#  ['Parmigiano Reggiano', 'escalope'],
#  ['assamese tea',
#   'pepper',
#   'french fries',
#   'strawberries',
#   'pancakes',
#   'low fat yogurt'],
#  ['oat pasta', 'frozen vegetables', 'yams', 'chicken', 'honey', 'light mayo'],
#  ['african yams', 'chocolate', 'champagne'],
#  ['baby corn', 'herb & pepper', 'honey', 'cake', 'rice', 'protein bar'],
#  ['grape wine',
#   'burgers',
#   'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'light mayo',
#   'asparagus'],
#  ['fresh chopped tuna',
#   'chocolate',
#   'mineral water',
#   'corn',
#   'cottage cheese',
#   'green tea'],
#  ['rock salt', 'muffins'],
#  ['whole wheat spagetti', 'ham', 'french wine', 'escalope'],
#  ['masala oatmeal', 'spaghetti', 'milk', 'whole wheat rice', 'mint green tea'],
#  ['seasoned herb & pepper', 'chocolate', 'body spray'],
#  ['assamese tea', 'frozen vegetables', 'french fries', 'hot dogs'],
#  ['antioxydant sour juice', 'candy bars'],
#  ['cream sauce',
#   'burgers',
#   'shrimp',
#   'pasta',
#   'milk',
#   'green tea',
#   'french fries',
#   'cookies',
#   'white wine'],
#  ['salted ground beef', 'parmesan cheese', 'ground beef'],
#  ['tomato chutney', 'pancakes', 'whole wheat rice', 'candy bars'],
#  ['boiled eggs', 'eggs', 'eggplant', 'cookies'],
#  ['dark chocolate', 'frozen vegetables', 'mineral water'],
#  ['glucose energy drink', 'chocolate'],
#  ['boiled eggs',
#   'turkey',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'chocolate'],
#  ['aged white wine',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'soup',
#   'meatballs',
#   'chicken',
#   'blueberries',
#   'cooking oil',
#   'champagne',
#   'yogurt cake',
#   'protein bar'],
#  ['oat pasta', 'cooking oil', 'tomato juice'],
#  ['fat milk',
#   'frozen vegetables',
#   'milk',
#   'eggs',
#   'french fries',
#   'green tea'],
#  ['potato chips',
#   'fresh tuna',
#   'spaghetti',
#   'olive oil',
#   'french wine',
#   'eggs',
#   'french fries',
#   'champagne',
#   'pancakes',
#   'light mayo'],
#  ['toned milk', 'red wine', 'honey', 'hot dogs'],
#  ['smelly cheese', 'milk', 'bacon', 'eggs', 'french fries', 'fresh bread'],
#  ['cheddar cheese', 'french fries', 'yogurt cake'],
#  ['baby corn', 'milk'],
#  ['cheddar cheese', 'french fries'],
#  ['mayonnaise dip', 'chocolate'],
#  ['burger mayo', 'burgers', 'ham', 'red wine'],
#  ['purple grapes',
#   'shrimp',
#   'pasta',
#   'tomatoes',
#   'energy bar',
#   'french wine',
#   'antioxydant juice',
#   'french fries',
#   'frozen smoothie',
#   'brownies'],
#  ['tomato chutney', 'green tea'],
#  ['barbecue powder', 'low fat yogurt'],
#  ['choco chip muffins',
#   'turkey',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'spinach',
#   'soda',
#   'energy drink',
#   'salt'],
#  ['masala oatmeal', 'turkey', 'eggs'],
#  ['frozen salad', 'bug spray', 'hot dogs'],
#  ['frozon vegetables mix', 'oil'],
#  ['baby corn',
#   'soup',
#   'energy bar',
#   'chicken',
#   'eggs',
#   'cake',
#   'french fries',
#   'body spray',
#   'strawberries'],
#  ['smoothie', 'spaghetti', 'chocolate', 'yogurt cake'],
#  ['mint powder', 'turkey', 'mineral water', 'meatballs'],
#  ['dark forest cake',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'fromage blanc',
#   'bacon',
#   'hot dogs'],
#  ['dry spinach',
#   'frozen vegetables',
#   'mineral water',
#   'vegetables mix',
#   'escalope'],
#  ['tomato chutney', 'herb & pepper', 'red wine', 'tomatoes'],
#  ['salted shrimp',
#   'whole wheat pasta',
#   'olive oil',
#   'cereals',
#   'brownies',
#   'green tea'],
#  ['multi-purpose essentials', 'cookies'],
#  ['chopped cauliflower', 'olive oil', 'cookies', 'mushroom cream sauce'],
#  ['mango pickles',
#   'ground beef',
#   'pancakes',
#   'cooking oil',
#   'gluten free bar',
#   'light mayo'],
#  ['antioxydant sour juice', 'mineral water', 'french fries'],
#  ['orange soda', 'herb & pepper'],
#  ['bubble gums', 'salmon'],
#  ['dark chocolate', 'eggs', 'escalope'],
#  ['tomatoes puree', 'mineral water', 'tomato juice'],
#  ['toned milk', 'mineral water'],
#  ['oat cereals', 'shrimp', 'mineral water', 'soup', 'black tea'],
#  ['baked asparagus', 'cake', 'frozen smoothie'],
#  ['golden honey',
#   'turkey',
#   'burgers',
#   'grated cheese',
#   'tomatoes',
#   'chocolate',
#   'fromage blanc',
#   'honey',
#   'whole wheat rice'],
#  ['flavored mayo',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'pancakes'],
#  ['golden honey',
#   'turkey',
#   'burgers',
#   'ground beef',
#   'milk',
#   'olive oil',
#   'cake',
#   'fresh bread'],
#  ['grape wine',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'soup',
#   'chutney',
#   'cereals',
#   'energy drink',
#   'protein bar'],
#  ['cheese sandwich',
#   'eggs',
#   'whole wheat rice',
#   'cake',
#   'green tea',
#   'escalope'],
#  ['french red wine',
#   'ground beef',
#   'yams',
#   'soup',
#   'avocado',
#   'salmon',
#   'green tea'],
#  ['pepper powder ', 'milk'],
#  ['strawberry sparkling water', 'spaghetti', 'chocolate'],
#  ['blue berry', 'whole wheat pasta', 'honey'],
#  ['smoothie', 'whole wheat pasta', 'green tea'],
#  ['flavored mayo', 'spaghetti', 'meatballs', 'vegetables mix', 'chocolate'],
#  ['sliced cheese', 'eggs', 'low fat yogurt'],
#  ['aged red wine',
#   'fresh tuna',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'olive oil',
#   'eggs',
#   'cake',
#   'brownies',
#   'tomato juice'],
#  ['water spray jet',
#   'mineral water',
#   'green grapes',
#   'hot dogs',
#   'fresh bread'],
#  ['salted toothpaste', 'frozen vegetables', 'meatballs', 'eggs', 'chocolate'],
#  ['salted shrimp', 'chocolate'],
#  ['lavender body spray', 'meatballs', 'milk'],
#  ['baked chicken', 'low fat yogurt'],
#  ['baby carrots ', 'green tea'],
#  ['peri peri french fries', 'escalope', 'pasta'],
#  ['white strawberries',
#   'pepper',
#   'chocolate',
#   'olive oil',
#   'french wine',
#   'salmon',
#   'rice',
#   'light mayo',
#   'fresh bread',
#   'magazines'],
#  ['roasted almonds',
#   'red wine',
#   'french wine',
#   'vegetables mix',
#   'rice',
#   'clothes accessories',
#   'hot dogs',
#   'green tea'],
#  ['glucose energy drink',
#   'burgers',
#   'dessert wine',
#   'spaghetti',
#   'chicken',
#   'cake',
#   'protein bar',
#   'green tea'],
#  ['multigrained flour', 'french wine', 'cake', 'fresh bread'],
#  ['peri peri french fries',
#   'burgers',
#   'frozen vegetables',
#   'flax seed',
#   'eggs'],
#  ['blue berry', 'red wine'],
#  ['african yams', 'pepper', 'mineral water', 'energy bar', 'green grapes'],
#  ['water', 'milk', 'eggs', 'cake', 'chocolate', 'french fries', 'green tea'],
#  ['honey lemon green tea', 'french fries'],
#  ['baby eggplant', 'almonds'],
#  ['smelly cheese', 'burgers', 'mineral water', 'green tea'],
#  ['sweet corn soup', 'milk', 'pancakes'],
#  ['browny fudge ', 'pancakes', 'eggs', 'salt', 'tomato juice'],
#  ['cheese sandwich', 'mineral water'],
#  ['multi-purpose essentials',
#   'ham',
#   'spaghetti',
#   'mineral water',
#   'olive oil'],
#  ['smoothie', 'salt', 'tomato juice', 'fresh bread'],
#  ['mustard hot dogs', 'spaghetti', 'mushroom cream sauce'],
#  ['brown bread', 'spaghetti', 'mineral water', 'eggs', 'pet food'],
#  ['baby carrots ', 'frozen vegetables', 'spaghetti'],
#  ['sliced fromage blanc ', 'energy drink'],
#  ['mango cream', 'muffins'],
#  ['fresh chopped tuna', 'turkey', 'milk'],
#  ['lemon black tea', 'cookies'],
#  ['burger mayo', 'chocolate'],
#  ['mint powder',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'chocolate',
#   'escalope'],
#  ['oat cereals',
#   'shrimp',
#   'frozen vegetables',
#   'pepper',
#   'spaghetti',
#   'green tea'],
#  ['aged white wine',
#   'burgers',
#   'fresh tuna',
#   'red wine',
#   'mineral water',
#   'french fries',
#   'hand protein bar',
#   'low fat yogurt'],
#  ['frozon vegetables mix', 'pancakes', 'eggs', 'energy drink', 'fresh bread'],
#  ['browny fudge ',
#   'strong cheese',
#   'salmon',
#   'green tea',
#   'french fries',
#   'frozen smoothie',
#   'hot dogs'],
#  ['baked asparagus',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'tomatoes',
#   'milk',
#   'frozen smoothie',
#   'sandwich'],
#  ['karetin shampoo',
#   'herb & pepper',
#   'whole wheat pasta',
#   'olive oil',
#   'pancakes',
#   'eggs'],
#  ['flavored mayo', 'spaghetti', 'antioxydant juice'],
#  ['choco chip cookies',
#   'chocolate',
#   'milk',
#   'almonds',
#   'eggs',
#   'strawberries',
#   'white wine'],
#  ['burger mayo', 'french fries', 'strawberries'],
#  ['vanila cake', 'mineral water'],
#  ['Parmigiano Reggiano', 'eggs'],
#  ['cloth napkins', 'escalope'],
#  ['tomato chutney', 'cake'],
#  ['burger mayo',
#   'whole wheat pasta',
#   'antioxydant juice',
#   'body spray',
#   'green tea'],
#  ['sliced fromage blanc ', 'mineral water', 'oil', 'frozen smoothie'],
#  ['african yams', 'french fries', 'champagne'],
#  ['baked asparagus', 'chocolate', 'french fries'],
#  ['chewy candy bars', 'frozen vegetables', 'spaghetti', 'eggs'],
#  ['apple cider', 'hot dogs'],
#  ['multigrained flour', 'chocolate', 'cookies'],
#  ['fat milk', 'pancakes'],
#  ['green chili', 'shrimp', 'butter', 'chicken', 'salmon'],
#  ['mayonnaise dip', 'chocolate', 'cookies', 'babies food'],
#  ['white strawberries',
#   'pepper',
#   'spaghetti',
#   'cake',
#   'chocolate',
#   'french fries',
#   'fresh bread'],
#  ['brown bread', 'avocado', 'oil', 'cereals', 'french fries'],
#  ['burger mayo',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'spinach',
#   'eggs',
#   'oil',
#   'cooking oil',
#   'green tea',
#   'shampoo',
#   'tomato juice',
#   'low fat yogurt'],
#  ['antioxydant sour juice',
#   'herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'pepper',
#   'spaghetti',
#   'mint green tea',
#   'french fries'],
#  ['canola olive oil', 'french fries'],
#  ['green chili', 'green tea', 'tomato juice'],
#  ['aged champagne', 'eggs', 'whole wheat rice', 'chocolate'],
#  ['mustard hot dogs',
#   'grated cheese',
#   'herb & pepper',
#   'red wine',
#   'spaghetti',
#   'mineral water',
#   'salmon',
#   'eggs',
#   'cooking oil',
#   'green tea'],
#  ['aged white wine',
#   'french fries',
#   'cookies',
#   'shallot',
#   'tomato juice',
#   'fresh bread',
#   'low fat yogurt'],
#  ['orange soda', 'burgers', 'fresh tuna', 'spaghetti', 'muffins', 'honey'],
#  ['salted ground beef',
#   'herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'eggs',
#   'chicken'],
#  ['aged white wine', 'grated cheese', 'muffins', 'tomato juice', 'mayonnaise'],
#  ['sliced fromage blanc ',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'muffins',
#   'frozen smoothie',
#   'hot dogs',
#   'energy drink'],
#  ['water spray jet',
#   'burgers',
#   'spaghetti',
#   'soup',
#   'milk',
#   'olive oil',
#   'salmon',
#   'eggs',
#   'blueberries'],
#  ['blue berry', 'chocolate', 'champagne', 'magazines'],
#  ['salted shrimp',
#   'frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'french wine',
#   'green grapes',
#   'rice',
#   'chocolate'],
#  ['frozen yogurt', 'tomato sauce', 'chocolate'],
#  ['pudina chutney', 'milk', 'eggs'],
#  ['dark forest cake', 'pet food'],
#  ['flax seed powder', 'yogurt cake'],
#  ['orange soda', 'green tea'],
#  ['beans', 'escalope', 'pasta'],
#  ['flax seed powder', 'herb & pepper', 'ground beef'],
#  ['cooked escalope', 'mineral water', 'honey', 'brownies'],
#  ['browny fudge ', 'turkey', 'eggs', 'cake', 'energy drink'],
#  ['lawn bug spray',
#   'turkey',
#   'burgers',
#   'dessert wine',
#   'ground beef',
#   'soup',
#   'salmon',
#   'eggs',
#   'gums',
#   'tomato juice',
#   'candy bars'],
#  ['grape wine', 'spaghetti', 'mineral water', 'chicken'],
#  ['grape wine', 'turkey', 'ground beef', 'carrots', 'french fries', 'melons'],
#  ['baked asparagus', 'mineral water', 'eggs', 'low fat yogurt'],
#  ['green chili', 'turkey', 'cooking oil', 'shampoo'],
#  ['sliced fromage blanc ', 'spaghetti', 'hot dogs'],
#  ['dry spinach', 'chocolate', 'green tea'],
#  ['oat cereals',
#   'grated cheese',
#   'pepper',
#   'mineral water',
#   'chocolate',
#   'eggs',
#   'cake',
#   'mashed potato',
#   'tomato juice'],
#  ['frozon vegetables mix', 'chocolate'],
#  ['dark chocolate', 'spaghetti', 'olive oil', 'strong cheese', 'pancakes'],
#  ['frozon vegetables mix',
#   'red wine',
#   'mineral water',
#   'soup',
#   'rice',
#   'cookies'],
#  ['pepper powder ', 'red wine', 'shrimp', 'spaghetti'],
#  ['mustard hot dogs', 'green tea'],
#  ['salted ground beef',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'frozen smoothie'],
#  ['fried meatballs', 'muffins'],
#  ['beans', 'cake', 'chocolate'],
#  ['protein fat bar',
#   'fresh tuna',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'avocado',
#   'meatballs',
#   'olive oil'],
#  ['baked asparagus', 'turkey', 'french fries'],
#  ['vanila cake',
#   'burgers',
#   'turkey',
#   'herb & pepper',
#   'ground beef',
#   'pancakes',
#   'eggs',
#   'light cream',
#   'rice',
#   'champagne',
#   'fresh bread'],
#  ['cheese sandwich', 'escalope'],
#  ['mint powder', 'chocolate', 'escalope', 'fresh bread'],
#  ['tomato chutney',
#   'ham',
#   'spaghetti',
#   'french wine',
#   'vegetables mix',
#   'chocolate',
#   'french fries'],
#  ['dog pet food', 'avocado', 'light mayo'],
#  ['baked turkey', 'spaghetti', 'yams', 'butter', 'chocolate'],
#  ['aged white wine', 'energy bar', 'eggs', 'french fries'],
#  ['canola olive oil', 'fresh tuna', 'barbecue sauce', 'eggplant'],
#  ['chewy candy bars', 'energy drink'],
#  ['vanila cake', 'whole wheat rice', 'french fries', 'hot dogs', 'green tea'],
#  ['baked chicken', 'mineral water', 'chicken', 'green tea'],
#  ['tomato chutney', 'eggs', 'cake', 'mushroom cream sauce'],
#  ['cooked spaghetti', 'escalope'],
#  ['fat milk', 'antioxydant juice', 'escalope'],
#  ['french red wine', 'shrimp', 'spaghetti', 'french fries'],
#  ['tomato chutney', 'grated cheese', 'spaghetti', 'salmon', 'tomato juice'],
#  ['multi-purpose essentials', 'spaghetti', 'green tea'],
#  ['african yams', 'champagne', 'protein bar'],
#  ['baked vegetables', 'mineral water', 'avocado', 'chocolate'],
#  ['baby corn', 'tomatoes', 'champagne', 'green tea'],
#  ['chewy candy bars', 'chicken', 'french fries', 'escalope'],
#  ['baby corn',
#   'frozen vegetables',
#   'tomatoes',
#   'eggs',
#   'green tea',
#   'frozen smoothie',
#   'light mayo'],
#  ['african yams',
#   'ground beef',
#   'chicken',
#   'cider',
#   'green grapes',
#   'honey',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'frozen smoothie',
#   'escalope'],
#  ['fried meatballs', 'french fries', 'champagne'],
#  ['white strawberries', 'mineral water', 'soup'],
#  ['golden honey',
#   'frozen vegetables',
#   'spaghetti',
#   'milk',
#   'chocolate',
#   'babies food'],
#  ['chopped cauliflower', 'honey', 'whole wheat rice'],
#  ['baby eggplant', 'whole wheat rice', 'chicken', 'tomato juice'],
#  ['dark forest cake', 'pancakes'],
#  ['masala oatmeal', 'green tea', 'protein bar', 'tomato juice', 'candy bars'],
#  ['fried meatballs', 'french fries'],
#  ['toned milk', 'mineral water'],
#  ['peri peri french fries', 'escalope'],
#  ['whole wheat spagetti',
#   'grated cheese',
#   'herb & pepper',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'bacon',
#   'nonfat milk',
#   'spinach'],
#  ['tomato chutney', 'spaghetti', 'milk'],
#  ['glucose energy bar', 'milk', 'chocolate', 'white wine'],
#  ['bramble', 'sandwich'],
#  ['veg burgers', 'chocolate', 'light mayo'],
#  ['masala oatmeal',
#   'shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'meatballs',
#   'chicken',
#   'frozen smoothie',
#   'tomato juice'],
#  ['burger mayo',
#   'red wine',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'eggs'],
#  ['white strawberries', 'yams', 'melons'],
#  ['mexican avocado', 'spaghetti', 'cooking oil'],
#  ['oat cereals', 'french fries'],
#  ['assamese tea',
#   'mineral water',
#   'milk',
#   'spinach',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie',
#   'hot dogs'],
#  ['cooked escalope', 'tomato sauce', 'milk'],
#  ['choco chip cookies', 'shrimp', 'cider', 'eggs', 'french fries'],
#  ['tomato chutney', 'champagne'],
#  ['mayonnaise dip', 'salad'],
#  ['green chili', 'french fries'],
#  ['vanila cake',
#   'frozen vegetables',
#   'mineral water',
#   'energy bar',
#   'honey',
#   'rice',
#   'green tea'],
#  ['frozen yogurt', 'french fries', 'salad'],
#  ['lavender body spray', 'honey', 'chocolate', 'french fries', 'brownies'],
#  ['protein fat bar', 'green tea', 'strawberries', 'gluten free bar'],
#  ['multi-grain bread',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'salmon',
#   'honey',
#   'extra dark chocolate',
#   'green tea',
#   'mushroom cream sauce',
#   'gluten free bar'],
#  ['frozen salad', 'grated cheese', 'tomatoes', 'mineral water', 'meatballs'],
#  ['toned milk', 'shrimp', 'chocolate', 'water spray'],
#  ['fat milk', 'turkey'],
#  ['black beauty zucchini', 'turkey', 'eggs'],
#  ['sweet corn soup',
#   'turkey',
#   'frozen vegetables',
#   'tomatoes',
#   'soup',
#   'butter',
#   'french wine',
#   'pancakes',
#   'eggs',
#   'tomato juice',
#   'fresh bread',
#   'green tea'],
#  ['oat pasta', 'spaghetti'],
#  ['blue berry', 'milk', 'frozen smoothie', 'low fat yogurt'],
#  ['choco chip muffins',
#   'burgers',
#   'mineral water',
#   'milk',
#   'whole wheat rice',
#   'cereals',
#   'chocolate',
#   'french fries'],
#  ['multi-grain bread', 'mineral water'],
#  ['frozen salad', 'tomatoes', 'mineral water', 'soup', 'cake', 'chocolate'],
#  ['purple grapes', 'mineral water'],
#  ['cooked spaghetti', 'ground beef', 'spaghetti'],
#  ['smoothie', 'pepper', 'frozen smoothie'],
#  ['white chocolate', 'yogurt cake'],
#  ['aged red wine', 'red wine', 'pancakes'],
#  ['frozen salad', 'candy bars'],
#  ['tomato chutney', 'eggs', 'french fries', 'low fat yogurt'],
#  ['brown bread', 'cookies'],
#  ['brown bread', 'cookies'],
#  ['rock salt',
#   'spaghetti',
#   'soup',
#   'vegetables mix',
#   'spinach',
#   'french fries',
#   'escalope',
#   'cauliflower',
#   'toothpaste'],
#  ['sliced fromage blanc ', 'cookies'],
#  ['sliced fromage blanc ', 'soup', 'olive oil', 'eggs', 'soda', 'corn'],
#  ['glucose energy drink', 'chocolate', 'frozen smoothie', 'low fat yogurt'],
#  ['browny fudge ',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'pancakes',
#   'chocolate',
#   'french fries'],
#  ['strawberry babies food', 'mineral water'],
#  ['strawberry babies food',
#   'herb & pepper',
#   'frozen vegetables',
#   'tomato sauce',
#   'mineral water',
#   'soup',
#   'milk',
#   'olive oil',
#   'almonds'],
#  ['coconut oil', 'burgers', 'eggs'],
#  ['fat milk', 'french fries'],
#  ['burger mayo', 'frozen smoothie', 'cottage cheese'],
#  ['protein bar', 'tomatoes', 'mineral water', 'chocolate', 'light mayo'],
#  ['cooked ham',
#   'salmon',
#   'escalope',
#   'shallot',
#   'strawberries',
#   'fresh bread',
#   'low fat yogurt'],
#  ['cooked ham', 'energy bar'],
#  ['flavored mayo',
#   'red wine',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'blueberries',
#   'oil',
#   'cooking oil',
#   'tomato juice'],
#  ['lemon black tea',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'frozen smoothie',
#   'champagne'],
#  ['baby carrots ', 'cookies'],
#  ['vanila cake', 'salmon', 'escalope'],
#  ['cooked spaghetti', 'cookies'],
#  ['dark forest cake', 'low fat yogurt'],
#  ['seasoned herb & pepper', 'eggs'],
#  ['mango cream', 'red wine', 'butter', 'hot dogs'],
#  ['bramble', 'tomatoes', 'mineral water', 'soup', 'mashed potato'],
#  ['tomato soup', 'cookies'],
#  ['rock salt',
#   'parmesan cheese',
#   'ground beef',
#   'salmon',
#   'pancakes',
#   'champagne'],
#  ['aged white wine', 'ground beef', 'yams', 'chocolate', 'olive oil', 'eggs'],
#  ['dog pet food', 'shrimp', 'salmon', 'eggs', 'cookies', 'hot dogs'],
#  ['white chocolate', 'magazines', 'mint'],
#  ['Parmigiano Reggiano',
#   'turkey',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'extra dark chocolate',
#   'escalope'],
#  ['tomato ketch up', 'mineral water', 'mushroom cream sauce'],
#  ['orange soda',
#   'grated cheese',
#   'frozen vegetables',
#   'mineral water',
#   'soup',
#   'milk',
#   'french wine'],
#  ['orange soda', 'chocolate', 'cake'],
#  ['burger mayo', 'burgers', 'salt', 'white wine'],
#  ['basmati rice', 'energy drink'],
#  ['sliced cheese', 'olive oil', 'cake', 'energy drink'],
#  ['strawberry babies food', 'ground beef', 'whole wheat rice'],
#  ['baked salmon', 'eggs', 'french fries'],
#  ['dark forest cake', 'spaghetti', 'escalope', 'mushroom cream sauce'],
#  ['aged white wine',
#   'mineral water',
#   'fromage blanc',
#   'whole wheat rice',
#   'cake',
#   'french fries'],
#  ['whipped cream',
#   'turkey',
#   'burgers',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'eggs',
#   'cake',
#   'light mayo'],
#  ['bramble', 'green tea', 'cottage cheese'],
#  ['strawberry sparkling water', 'fresh tuna', 'eggs', 'champagne'],
#  ['veg burgers', 'cookies'],
#  ['cooked ham', 'cookies'],
#  ['whole wheat spagetti', 'cookies'],
#  ['green chili', 'tomatoes', 'mineral water', 'eggplant'],
#  ['mustard hot dogs',
#   'grated cheese',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'honey',
#   'chicken',
#   'chocolate',
#   'french fries'],
#  ['sliced cheese', 'protein bar'],
#  ['toned milk',
#   'herb & pepper',
#   'red wine',
#   'shrimp',
#   'mineral water',
#   'barbecue sauce',
#   'protein bar'],
#  ['tomato chutney',
#   'burgers',
#   'ham',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'french fries',
#   'escalope',
#   'pancakes',
#   'low fat yogurt'],
#  ['fat milk', 'french fries'],
#  ['masala oatmeal',
#   'frozen vegetables',
#   'soup',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'chocolate',
#   'escalope',
#   'melons'],
#  ['aged champagne', 'spaghetti'],
#  ['basmati rice',
#   'herb & pepper',
#   'shrimp',
#   'soup',
#   'eggs',
#   'oil',
#   'cooking oil',
#   'energy drink',
#   'protein bar',
#   'low fat yogurt'],
#  ['smoothie',
#   'ham',
#   'grated cheese',
#   'herb & pepper',
#   'shrimp',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'carrots'],
#  ['oat cereals',
#   'ham',
#   'red wine',
#   'ground beef',
#   'yams',
#   'mineral water',
#   'chocolate',
#   'low fat yogurt'],
#  ['salted toothpaste',
#   'chocolate',
#   'french fries',
#   'mushroom cream sauce',
#   'cottage cheese',
#   'low fat yogurt'],
#  ['brown bread', 'eggs'],
#  ['lavender body spray', 'cake', 'cookies'],
#  ['canola olive oil',
#   'grated cheese',
#   'mineral water',
#   'cake',
#   'chocolate bread'],
#  ['strawberry sparkling water',
#   'tomatoes',
#   'almonds',
#   'cake',
#   'champagne',
#   'low fat yogurt'],
#  ['glucose energy drink',
#   'herb & pepper',
#   'shrimp',
#   'frozen vegetables',
#   'milk',
#   'butter',
#   'salmon',
#   'eggs',
#   'chocolate'],
#  ['aged champagne',
#   'herb & pepper',
#   'shrimp',
#   'whole wheat pasta',
#   'whole wheat rice',
#   'chicken',
#   'green tea',
#   'cauliflower'],
#  ['frozon vegetables mix', 'eggs', 'corn'],
#  ['mint powder',
#   'shrimp',
#   'frozen vegetables',
#   'tomato sauce',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'olive oil',
#   'salmon',
#   'green beans',
#   'champagne'],
#  ['lemon black tea',
#   'ham',
#   'herb & pepper',
#   'tomato sauce',
#   'mineral water',
#   'green grapes',
#   'eggs',
#   'gums',
#   'light cream',
#   'oil',
#   'green tea',
#   'mint'],
#  ['multi-purpose essentials', 'energy bar', 'cake', 'chocolate'],
#  ['seasoned herb & pepper', 'herb & pepper', 'shrimp', 'spaghetti', 'eggs'],
#  ['choco chip cookies', 'fresh tuna', 'mineral water', 'honey', 'cooking oil'],
#  ['sliced cheese',
#   'red wine',
#   'mineral water',
#   'oil',
#   'ketchup',
#   'chili',
#   'pet food',
#   'eggplant',
#   'green tea',
#   'escalope',
#   'tomato juice',
#   'low fat yogurt'],
#  ['cheddar cheese',
#   'herb & pepper',
#   'shrimp',
#   'mineral water',
#   'pancakes',
#   'eggs',
#   'cake',
#   'blueberries',
#   'tea',
#   'frozen smoothie'],
#  ['baby eggplant', 'ground beef', 'mineral water', 'protein bar'],
#  ['frozon vegetables mix',
#   'shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'spaghetti',
#   'salmon',
#   'carrots',
#   'frozen smoothie',
#   'pasta',
#   'mashed potato',
#   'shallot',
#   'light mayo',
#   'magazines'],
#  ['flax seed powder', 'milk', 'chocolate'],
#  ['dark chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'spaghetti',
#   'olive oil',
#   'whole wheat rice',
#   'eggplant',
#   'cottage cheese'],
#  ['dry spinach', 'turkey', 'ground beef', 'low fat yogurt'],
#  ['salted ground beef',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'whole wheat rice',
#   'cake',
#   'hot dogs',
#   'green tea'],
#  ['black beauty zucchini', 'green tea'],
#  ['canola olive oil', 'cookies'],
#  ['multigrained flour', 'eggs', 'cookies'],
#  ['pepper powder ',
#   'spaghetti',
#   'eggs',
#   'ham',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'brownies',
#   'pancakes',
#   'light mayo'],
#  ['glucose energy bar', 'red wine', 'spaghetti', 'milk', 'eggs', 'chocolate'],
#  ['french red wine',
#   'turkey',
#   'burgers',
#   'pancakes',
#   'french fries',
#   'strawberries',
#   'green tea'],
#  ['mayonnaise dip', 'escalope'],
#  ['masala oatmeal', 'frozen vegetables', 'pancakes', 'eggs', 'cake'],
#  ['apple cider', 'french fries'],
#  ['smoothie',
#   'turkey',
#   'ground beef',
#   'pepper',
#   'spaghetti',
#   'honey',
#   'cookies'],
#  ['tomatoes puree',
#   'chocolate',
#   'red wine',
#   'tomato sauce',
#   'olive oil',
#   'chili',
#   'french fries',
#   'cookies',
#   'salt',
#   'fresh bread',
#   'magazines'],
#  ['peri peri french fries', 'green tea', 'french fries'],
#  ['pudina chutney', 'mineral water'],
#  ['lawn bug spray', 'cooking oil'],
#  ['chopped cauliflower', 'frozen vegetables', 'spaghetti'],
#  ['pepper powder ', 'ham', 'spaghetti'],
#  ['boiled eggs', 'chicken', 'chocolate', 'cookies'],
#  ['orange soda', 'low fat yogurt'],
#  ['honey lemon green tea', 'eggs', 'cake', 'low fat yogurt'],
#  ['choco chip muffins',
#   'shrimp',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'bramble',
#   'frozen smoothie',
#   'cottage cheese'],
#  ['burger mayo', 'mineral water', 'eggs', 'protein bar'],
#  ['antioxydant sour juice',
#   'turkey',
#   'shrimp',
#   'meatballs',
#   'butter',
#   'eggs',
#   'salad',
#   'green tea'],
#  ['fresh chopped tuna',
#   'fresh tuna',
#   'spaghetti',
#   'chocolate',
#   'olive oil',
#   'chicken',
#   'french fries'],
#  ['cheese sandwich', 'turkey', 'shrimp', 'escalope', 'hot dogs'],
#  ['beans', 'burgers', 'pepper', 'soup', 'milk', 'pancakes', 'green tea'],
#  ['mustard hot dogs', 'pancakes'],
#  ['water spray jet', 'mineral water', 'pancakes', 'eggs', 'french fries'],
#  ['baby eggplant', 'eggs', 'escalope', 'low fat yogurt'],
#  ['smoothie', 'mineral water', 'french wine', 'gluten free bar'],
#  ['frozen salad',
#   'burgers',
#   'ground beef',
#   'spaghetti',
#   'eggs',
#   'french fries'],
#  ['fat milk', 'soup', 'meatballs', 'milk', 'energy bar'],
#  ['orange soda', 'chocolate'],
#  ['lavender body spray', 'herb & pepper'],
#  ['water', 'turkey', 'red wine', 'mineral water', 'eggs', 'bramble'],
#  ['mint powder',
#   'burgers',
#   'ham',
#   'frozen vegetables',
#   'tomatoes',
#   'cake',
#   'chicken',
#   'green tea',
#   'toothpaste',
#   'mint'],
#  ['oat pasta', 'grated cheese', 'mineral water', 'olive oil', 'energy bar'],
#  ['green chili', 'milk', 'cake', 'green tea'],
#  ['musk melons',
#   'mineral water',
#   'almonds',
#   'cooking oil',
#   'cereals',
#   'protein bar',
#   'white wine',
#   'green tea'],
#  ['honey lemon green tea',
#   'turkey',
#   'fresh tuna',
#   'mineral water',
#   'milk',
#   'eggs',
#   'cake',
#   'burger sauce',
#   'chicken',
#   'french fries',
#   'frozen smoothie',
#   'fresh bread'],
#  ['lemon black tea',
#   'herb & pepper',
#   'mineral water',
#   'whole wheat rice',
#   'yogurt cake',
#   'low fat yogurt'],
#  ['fried meatballs', 'tomatoes', 'spaghetti', 'meatballs', 'chicken', 'eggs'],
#  ['african yams', 'burgers', 'mineral water', 'eggs', 'green tea', 'pancakes'],
#  ['chopped cauliflower', 'cake', 'green tea'],
#  ['mango cream', 'chocolate', 'herb & pepper', 'yogurt cake'],
#  ['mango cream',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'salmon',
#   'nonfat milk',
#   'green grapes',
#   'pancakes'],
#  ['fresh chopped tuna', 'mineral water', 'vegetables mix', 'eggs'],
#  ['apple cider', 'protein bar'],
#  ['mint powder', 'eggs', 'eggplant'],
#  ['mayonnaise dip', 'mayonnaise'],
#  ['salted butter', 'milk', 'bug spray', 'oatmeal', 'sandwich', 'asparagus'],
#  ['protein bar',
#   'frozen vegetables',
#   'soup',
#   'almonds',
#   'eggs',
#   'french fries'],
#  ['frozen yogurt', 'frozen vegetables'],
#  ['mustard hot dogs', 'soup', 'butter', 'shampoo'],
#  ['cooked escalope', 'herb & pepper', 'whole wheat pasta', 'pepper', 'eggs'],
#  ['tomato ketch up',
#   'mineral water',
#   'whole wheat rice',
#   'rice',
#   'cooking oil',
#   'chocolate',
#   'fresh bread',
#   'low fat yogurt'],
#  ['multi-grain bread',
#   'grated cheese',
#   'butter',
#   'chocolate',
#   'french fries',
#   'cookies'],
#  ['chopped cauliflower',
#   'spaghetti',
#   'soup',
#   'milk',
#   'chutney',
#   'cooking oil',
#   'asparagus',
#   'tomato juice'],
#  ['barbecue powder',
#   'eggs',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'champagne',
#   'cottage cheese',
#   'green tea'],
#  ['white chocolate',
#   'turkey',
#   'tomatoes',
#   'mineral water',
#   'eggs',
#   'blueberries'],
#  ['rock salt', 'milk', 'tomato juice', 'low fat yogurt', 'green tea'],
#  ['glucose energy bar',
#   'mineral water',
#   'soup',
#   'almonds',
#   'cereals',
#   'green tea'],
#  ['choco chip muffins', 'chocolate', 'light mayo'],
#  ['coconut oil', 'turkey', 'herb & pepper', 'chocolate'],
#  ['baby corn', 'eggs', 'french fries', 'green tea'],
#  ['boiled eggs', 'mineral water', 'cake', 'chocolate', 'tomato juice'],
#  ['cooked ham', 'eggs'],
#  ['cheddar cheese',
#   'chocolate',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'whole wheat rice',
#   'champagne',
#   'mushroom cream sauce'],
#  ['orange soda',
#   'frozen vegetables',
#   'pepper',
#   'mineral water',
#   'chocolate',
#   'white wine'],
#  ['baby corn',
#   'burgers',
#   'turkey',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'oil',
#   'tomato juice',
#   'green tea'],
#  ['water',
#   'burgers',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'french wine',
#   'french fries',
#   'light mayo',
#   'low fat yogurt'],
#  ['lemon black tea',
#   'butter',
#   'green grapes',
#   'frozen smoothie',
#   'low fat yogurt'],
#  ['protein fat bar', 'eggs', 'low fat yogurt'],
#  ['flavored mayo', 'cookies'],
#  ['aged red wine', 'milk', 'energy drink'],
#  ['protein fat bar', 'olive oil', 'energy drink'],
#  ['mustard hot dogs', 'eggs', 'cookies'],
#  ['aged red wine', 'eggs'],
#  ['multi-grain bread', 'energy bar', 'eggs'],
#  ['cloth napkins', 'eggs'],
#  ['grape wine', 'eggs', 'green tea'],
#  ['honey lemon green tea', 'escalope'],
#  ['Parmigiano Reggiano',
#   'shrimp',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'oil',
#   'chocolate'],
#  ['cheese sandwich', 'chocolate', 'french fries'],
#  ['bramble', 'cake'],
#  ['choco chip cookies', 'pancakes', 'eggs', 'cake', 'green tea', 'toothpaste'],
#  ['honey lemon green tea',
#   'herb & pepper',
#   'tomatoes',
#   'ground beef',
#   'eggs',
#   'cooking oil'],
#  ['salted ground beef', 'cider', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['toned milk', 'frozen vegetables', 'cider', 'eggs', 'french fries'],
#  ['sweet corn soup', 'yams', 'cookies', 'toothpaste'],
#  ['salted ground beef',
#   'mineral water',
#   'milk',
#   'escalope',
#   'champagne',
#   'hot dogs',
#   'fresh bread'],
#  ['fresh chopped tuna',
#   'ham',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'pancakes',
#   'eggs'],
#  ['salted butter',
#   'pepper',
#   'mineral water',
#   'escalope',
#   'shallot',
#   'protein bar',
#   'white wine'],
#  ['golden honey',
#   'turkey',
#   'parmesan cheese',
#   'spaghetti',
#   'meatballs',
#   'butter'],
#  ['sliced fromage blanc ', 'herb & pepper', 'eggs', 'escalope'],
#  ['aged red wine', 'herb & pepper'],
#  ['aged champagne', 'burgers', 'escalope', 'shallot'],
#  ['dark forest cake', 'chocolate', 'pepper', 'tomato sauce', 'tomato juice'],
#  ['veg burgers', 'cookies'],
#  ['cooked escalope',
#   'burgers',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'escalope',
#   'melons'],
#  ['lemon black tea',
#   'frozen vegetables',
#   'mineral water',
#   'soup',
#   'milk',
#   'olive oil'],
#  ['green chili',
#   'turkey',
#   'eggs',
#   'french fries',
#   'asparagus',
#   'low fat yogurt',
#   'zucchini'],
#  ['cheddar cheese', 'burgers', 'frozen vegetables', 'gums'],
#  ['white chocolate',
#   'herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'milk'],
#  ['golden honey', 'frozen vegetables', 'cake', 'light cream', 'mashed potato'],
#  ['seasoned herb & pepper', 'milk'],
#  ['low fat cooking oil', 'turkey', 'eggs', 'barbecue sauce'],
#  ['lemon black tea', 'escalope'],
#  ['antioxydant sour juice', 'parmesan cheese', 'french fries'],
#  ['lawn bug spray', 'energy bar', 'eggs'],
#  ['sliced fromage blanc ', 'soup', 'escalope', 'mint'],
#  ['browny fudge ', 'muffins', 'chicken', 'zucchini'],
#  ['frozen salad', 'burgers', 'eggs', 'french fries', 'cookies', 'green tea'],
#  ['lavender body spray', 'spaghetti'],
#  ['apple cider', 'avocado', 'energy bar', 'chocolate'],
#  ['purple grapes', 'cookies'],
#  ['mexican avocado', 'green tea'],
#  ['mexican avocado',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'olive oil'],
#  ['honey lemon green tea',
#   'grated cheese',
#   'frozen vegetables',
#   'eggs',
#   'gums',
#   'escalope',
#   'low fat yogurt'],
#  ['strawberry babies food',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'pancakes',
#   'chocolate',
#   'escalope',
#   'tomato juice'],
#  ['multi-grain bread',
#   'chocolate',
#   'spaghetti',
#   'yams',
#   'flax seed',
#   'salmon',
#   'frozen smoothie'],
#  ['mint powder', 'burger sauce', 'oil'],
#  ['aged champagne', 'eggs', 'french fries', 'energy drink'],
#  ['chewy candy bars', 'mineral water'],
#  ['brown bread', 'grated cheese', 'ground beef', 'mineral water', 'olive oil'],
#  ['sweet corn soup', 'eggs', 'low fat yogurt'],
#  ['brown rice',
#   'parmesan cheese',
#   'spaghetti',
#   'soda',
#   'pet food',
#   'white wine'],
#  ['fresh chopped tuna',
#   'turkey',
#   'shrimp',
#   'olive oil',
#   'chicken',
#   'eggs',
#   'extra dark chocolate',
#   'melons',
#   'fresh bread'],
#  ['protein fat bar',
#   'pickles',
#   'ground beef',
#   'yams',
#   'milk',
#   'strong cheese',
#   'salmon',
#   'muffins',
#   'french fries',
#   'escalope'],
#  ['choco chip cookies', 'pepper', 'spaghetti', 'light cream'],
#  ['baked chicken', 'frozen vegetables', 'mineral water', 'eggs'],
#  ['dark forest cake',
#   'spaghetti',
#   'chicken',
#   'tea',
#   'pancakes',
#   'gluten free bar'],
#  ['rock salt',
#   'fresh tuna',
#   'turkey',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'mint'],
#  ['mango cream', 'spaghetti', 'mineral water', 'cooking oil', 'escalope'],
#  ['flax seed powder', 'soup'],
#  ['fat milk', 'burgers', 'herb & pepper', 'spaghetti'],
#  ['dog pet food', 'cookies', 'shallot', 'strawberries'],
#  ['strong mint green tea',
#   'fresh tuna',
#   'chocolate',
#   'shrimp',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'soup',
#   'milk',
#   'salmon'],
#  ['dry spinach',
#   'yams',
#   'mineral water',
#   'avocado',
#   'milk',
#   'butter',
#   'cooking oil',
#   'chocolate',
#   'cottage cheese'],
#  ['protein fat bar', 'ham', 'eggs', 'french fries', 'energy drink'],
#  ['chewy candy bars', 'mineral water', 'avocado'],
#  ['salted ground beef', 'cookies'],
#  ['aged white wine',
#   'chocolate',
#   'butter',
#   'eggs',
#   'green tea',
#   'cottage cheese',
#   'mayonnaise'],
#  ['sweet corn soup', 'eggs', 'mushroom cream sauce', 'low fat yogurt'],
#  ['vanila cake', 'antioxydant juice', 'chocolate'],
#  ['apple cider', 'ground beef', 'spaghetti', 'french fries', 'green tea'],
#  ['cloth napkins', 'cake'],
#  ['salted butter',
#   'turkey',
#   'red wine',
#   'mineral water',
#   'pancakes',
#   'eggs',
#   'whole wheat rice',
#   'cooking oil',
#   'chocolate',
#   'zucchini'],
#  ['lavender body spray',
#   'chocolate',
#   'parmesan cheese',
#   'mineral water',
#   'olive oil',
#   'bacon'],
#  ['boiled eggs', 'green grapes', 'gums'],
#  ['honey lemon green tea',
#   'shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'milk',
#   'eggs',
#   'cooking oil',
#   'chocolate',
#   'french fries'],
#  ['flavored mayo', 'ground beef', 'mineral water', 'milk', 'eggs'],
#  ['tomatoes puree', 'escalope'],
#  ['brown rice', 'turkey', 'cookies'],
#  ['choco chip cookies',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'green tea'],
#  ['lemon black tea',
# ...
#   'parmesan cheese',
#   'ground beef',
#   'tomato sauce',
#   'milk',
#   'extra dark chocolate',
#   'melons',
#   'mint',
#   'green tea'],
#  ['brown bread', 'olive oil', 'chicken', 'chocolate', 'cookies', 'green tea'],
#  ['mayonnaise dip',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'french wine',
#   'pancakes',
#   'eggs',
#   'frozen smoothie',
#   'sandwich',
#   'tomato juice'],
#  ['mayonnaise dip', 'eggs', 'cottage cheese'],
#  ['Parmigiano Reggiano', 'muffins', 'cottage cheese'],
#  ['dog pet food', 'green tea', 'frozen smoothie', 'white wine'],
#  ['frozon vegetables mix', 'mineral water', 'chocolate', 'rice', 'champagne'],
#  ['aged red wine', 'mineral water'],
#  ['strawberry babies food',
#   'shrimp',
#   'whole wheat pasta',
#   'meatballs',
#   'milk'],
#  ['grape wine',
#   'herb & pepper',
#   'parmesan cheese',
#   'ground beef',
#   'pepper',
#   'spaghetti',
#   'cream',
#   'black tea',
#   'almonds',
#   'french wine',
#   'pancakes',
#   'eggs'],
#  ['smelly cheese',
#   'grated cheese',
#   'shrimp',
#   'parmesan cheese',
#   'ground beef',
#   'mineral water',
#   'mint'],
#  ['orange soda', 'mineral water', 'rice'],
#  ['browny fudge ', 'pancakes'],
#  ['african yams', 'mineral water', 'honey'],
#  ['mint powder', 'burgers', 'ground beef', 'pancakes', 'salt'],
#  ['vanila cake', 'parmesan cheese', 'soda', 'french fries', 'brownies'],
#  ['salted shrimp', 'whole wheat rice'],
#  ['baked salmon',
#   'ground beef',
#   'spaghetti',
#   'chicken',
#   'rice',
#   'oil',
#   'cooking oil',
#   'hot dogs',
#   'mint'],
#  ['bramble', 'butter', 'chocolate'],
#  ['oat cereals', 'pepper'],
#  ['lawn bug spray',
#   'herb & pepper',
#   'chocolate',
#   'champagne',
#   'yogurt cake',
#   'green tea'],
#  ['choco chip cookies', 'grated cheese', 'mineral water', 'eggs', 'escalope'],
#  ['seasoned herb & pepper',
#   'cookies',
#   'yogurt cake',
#   'light mayo',
#   'green tea'],
#  ['dog pet food', 'milk', 'cooking oil'],
#  ['tomato soup',
#   'milk',
#   'olive oil',
#   'light cream',
#   'cooking oil',
#   'chicken',
#   'extra dark chocolate',
#   'cereals',
#   'french fries',
#   'frozen smoothie',
#   'pancakes',
#   'tomato juice',
#   'fresh bread',
#   'low fat yogurt'],
#  ['tomato chutney',
#   'tomatoes',
#   'soup',
#   'avocado',
#   'milk',
#   'yogurt cake',
#   'energy drink',
#   'low fat yogurt',
#   'green tea'],
#  ['salted butter', 'ham', 'chocolate', 'ground beef', 'mineral water', 'oil'],
#  ['boiled eggs', 'green tea', 'champagne', 'escalope'],
#  ['white strawberries', 'chocolate'],
#  ['frozen yogurt', 'escalope', 'pasta'],
#  ['choco chip muffins',
#   'burgers',
#   'mineral water',
#   'olive oil',
#   'rice',
#   'antioxydant juice',
#   'frozen smoothie'],
#  ['pink shallot', 'green tea'],
#  ['baby carrots ',
#   'grated cheese',
#   'tomato sauce',
#   'spaghetti',
#   'milk',
#   'pancakes',
#   'energy drink',
#   'white wine'],
#  ['basmati rice', 'turkey', 'spaghetti', 'strong cheese', 'strawberries'],
#  ['french red wine', 'muffins'],
#  ['dry spinach',
#   'ground beef',
#   'spaghetti',
#   'cider',
#   'cooking oil',
#   'cookies'],
#  ['cream sauce',
#   'burgers',
#   'frozen vegetables',
#   'parmesan cheese',
#   'spaghetti',
#   'fromage blanc',
#   'vegetables mix',
#   'pancakes',
#   'honey',
#   'hot dogs',
#   'low fat yogurt'],
#  ['lawn bug spray', 'ground beef'],
#  ['multi-purpose essentials', 'green beans'],
#  ['mango cream',
#   'frozen vegetables',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'champagne',
#   'escalope'],
#  ['oat pasta',
#   'parmesan cheese',
#   'milk',
#   'butter',
#   'black tea',
#   'eggs',
#   'frozen smoothie',
#   'light mayo',
#   'shampoo',
#   'low fat yogurt',
#   'green tea'],
#  ['multi-grain bread', 'mineral water', 'cake'],
#  ['african yams',
#   'turkey',
#   'mineral water',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'cooking oil',
#   'frozen smoothie',
#   'cookies',
#   'green tea'],
#  ['french red wine', 'avocado', 'chocolate', 'french fries'],
#  ['mint powder', 'green tea'],
#  ['frozen yogurt', 'chocolate', 'eggs', 'bug spray'],
#  ['veg burgers', 'grated cheese', 'muffins', 'french fries', 'body spray'],
#  ['basmati rice', 'mineral water', 'eggs', 'blueberries', 'soda', 'escalope'],
#  ['barbecue powder', 'whole wheat rice'],
#  ['salted toothpaste', 'nonfat milk', 'cookies', 'mushroom cream sauce'],
#  ['baked vegetables', 'french fries', 'champagne'],
#  ['vanila cake', 'mineral water', 'salmon'],
#  ['tomatoes puree', 'olive oil'],
#  ['cheese sandwich',
#   'turkey',
#   'tomatoes',
#   'ground beef',
#   'soup',
#   'milk',
#   'butter',
#   'honey',
#   'cake',
#   'mint green tea',
#   'brownies',
#   'salt'],
#  ['aged champagne',
#   'parmesan cheese',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'napkins',
#   'low fat yogurt'],
#  ['brown rice',
#   'burgers',
#   'parmesan cheese',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   'energy bar',
#   'butter',
#   'almonds',
#   'fromage blanc',
#   'eggs',
#   'cake',
#   'pancakes'],
#  ['honey lemon green tea',
#   'shrimp',
#   'honey',
#   'pasta',
#   'energy drink',
#   'green tea'],
#  ['cheddar cheese',
#   'fresh tuna',
#   'chocolate',
#   'milk',
#   'french wine',
#   'muffins',
#   'pancakes',
#   'champagne',
#   'frozen smoothie'],
#  ['water spray jet', 'strawberries'],
#  ['smelly cheese', 'herb & pepper'],
#  ['baked vegetables',
#   'herb & pepper',
#   'frozen vegetables',
#   'tomatoes',
#   'parmesan cheese',
#   'ground beef',
#   'fromage blanc',
#   'eggs',
#   'honey',
#   'cake',
#   'rice',
#   'cereals',
#   'french fries',
#   'champagne'],
#  ['tomatoes puree',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'strong cheese',
#   'cereals',
#   'escalope',
#   'cottage cheese'],
#  ['mustard hot dogs',
#   'turkey',
#   'burgers',
#   'fresh tuna',
#   'spaghetti',
#   'pancakes',
#   'eggs',
#   'cake',
#   'cottage cheese',
#   'energy drink',
#   'gluten free bar'],
#  ['browny fudge ', 'eggplant'],
#  ['pink shallot',
#   'burgers',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'honey',
#   'extra dark chocolate',
#   'carrots',
#   'mashed potato'],
#  ['boiled eggs',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cottage cheese',
#   'strawberries',
#   'light mayo'],
#  ['glucose energy bar', 'strong cheese'],
#  ['salted butter', 'chocolate', 'french fries'],
#  ['strawberry sparkling water', 'chocolate', 'french fries', 'strawberries'],
#  ['baked vegetables',
#   'turkey',
#   'frozen vegetables',
#   'avocado',
#   'cake',
#   'light cream',
#   'cooking oil',
#   'chicken',
#   'chocolate bread',
#   'mashed potato'],
#  ['tomato ketch up', 'olive oil', 'energy bar', 'shallot'],
#  ['black beauty zucchini', 'turkey', 'shrimp'],
#  ['baked turkey', 'chocolate', 'spaghetti', 'champagne', 'yogurt cake'],
#  ['green chili',
#   'shrimp',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'butter',
#   'zucchini',
#   'green tea'],
#  ['chopped cauliflower', 'muffins', 'green tea', 'brownies'],
#  ['roasted almonds', 'yogurt cake'],
#  ['aged champagne',
#   'turkey',
#   'tomato sauce',
#   'milk',
#   'butter',
#   'bacon',
#   'salmon',
#   'cooking oil',
#   'chocolate',
#   'french fries',
#   'hot dogs',
#   'melons',
#   'protein bar',
#   'mint'],
#  ['veg burgers', 'grated cheese'],
#  ['brown rice', 'butter', 'burger sauce', 'brownies', 'pancakes'],
#  ['tomatoes puree',
#   'butter',
#   'pancakes',
#   'whole wheat rice',
#   'green tea',
#   'french fries',
#   'cookies',
#   'shallot',
#   'low fat yogurt'],
#  ['strawberry babies food',
#   'shrimp',
#   'chocolate',
#   'butter',
#   'cooking oil',
#   'escalope'],
#  ['salted toothpaste',
#   'burgers',
#   'red wine',
#   'frozen vegetables',
#   'pepper',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'honey',
#   'whole wheat rice',
#   'cooking oil',
#   'cereals'],
#  ['pink shallot',
#   'turkey',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'eggs',
#   'cake',
#   'chili',
#   'pet food',
#   'chocolate'],
#  ['glucose energy drink',
#   'shrimp',
#   'milk',
#   'butter',
#   'chicken',
#   'salt',
#   'mayonnaise',
#   'green tea'],
#  ['protein bar',
#   'fresh tuna',
#   'mineral water',
#   'fromage blanc',
#   'honey',
#   'gums',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'sparkling water',
#   'strawberries',
#   'green tea'],
#  ['masala oatmeal', 'chocolate', 'cookies'],
#  ['brown bread', 'sparkling water', 'light mayo'],
#  ['multigrained flour',
#   'frozen vegetables',
#   'tomatoes',
#   'spaghetti',
#   'chicken',
#   'french fries',
#   'escalope'],
#  ['multi-purpose essentials',
#   'turkey',
#   'burgers',
#   'butter',
#   'vegetables mix',
#   'green grapes',
#   'pancakes',
#   'eggs',
#   'cake',
#   'barbecue sauce',
#   'green tea'],
#  ['sliced fromage blanc ',
#   'red wine',
#   'shrimp',
#   'yams',
#   'eggs',
#   'burger sauce',
#   'yogurt cake'],
#  ['pink shallot', 'french fries', 'light mayo'],
#  ['aged red wine',
#   'burgers',
#   'ground beef',
#   'eggs',
#   'chocolate',
#   'champagne',
#   'zucchini'],
#  ['golden honey', 'mushroom cream sauce'],
#  ['musk melons', 'butter', 'mint green tea'],
#  ['salted ground beef', 'whole wheat rice'],
#  ['baby carrots ', 'gums'],
#  ['baked vegetables',
#   'mineral water',
#   'french fries',
#   'champagne',
#   'green tea'],
#  ['mango pickles', 'cereals', 'salt', 'green tea'],
#  ['musk melons',
#   'shrimp',
#   'spaghetti',
#   'chocolate',
#   'french fries',
#   'escalope',
#   'cookies',
#   'brownies',
#   'pancakes',
#   'melons'],
#  ['aged red wine',
#   'ham',
#   'spaghetti',
#   'yams',
#   'chicken',
#   'cooking oil',
#   'chocolate',
#   'hot dogs'],
#  ['antioxydant sour juice', 'eggs'],
#  ['rock salt',
#   'ground beef',
#   'olive oil',
#   'bug spray',
#   'frozen smoothie',
#   'hot dogs'],
#  ['salted shrimp',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'escalope'],
#  ['Parmigiano Reggiano',
#   'whole wheat rice',
#   'oil',
#   'chicken',
#   'french fries',
#   'escalope'],
#  ['baked turkey', 'green tea'],
#  ['tomato chutney',
#   'parmesan cheese',
#   'whole wheat rice',
#   'escalope',
#   'champagne'],
#  ['water spray jet',
#   'fresh tuna',
#   'frozen vegetables',
#   'chicken',
#   'fromage blanc',
#   'honey',
#   'light mayo'],
#  ['baked chicken', 'ground beef'],
#  ['lavender body spray',
#   'muffins',
#   'champagne',
#   'cookies',
#   'fresh bread',
#   'green tea'],
#  ['mayonnaise dip',
#   'frozen vegetables',
#   'spaghetti',
#   'chocolate',
#   'escalope',
#   'fresh bread'],
#  ['boiled eggs', 'pickles', 'spaghetti', 'french fries', 'frozen smoothie'],
#  ['boiled eggs', 'avocado'],
#  ['baked vegetables', 'sandwich'],
#  ['strawberry sparkling water', 'spaghetti', 'milk', 'oil', 'shampoo'],
#  ['salted toothpaste', 'champagne'],
#  ['frozon vegetables mix', 'spaghetti'],
#  ['salted ground beef', 'champagne'],
#  ['pink shallot', 'avocado', 'milk', 'butter', 'french fries', 'cookies'],
#  ['frozen yogurt',
#   'turkey',
#   'frozen vegetables',
#   'chicken',
#   'eggs',
#   'frozen smoothie',
#   'cauliflower',
#   'low fat yogurt'],
#  ['masala oatmeal',
#   'burgers',
#   'shrimp',
#   'tomatoes',
#   'milk',
#   'energy bar',
#   'almonds',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'body spray'],
#  ['aged white wine',
#   'burgers',
#   'milk',
#   'cake',
#   'cooking oil',
#   'french fries',
#   'escalope',
#   'zucchini'],
#  ['choco chip cookies',
#   'tomatoes',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'frozen smoothie',
#   'protein bar'],
#  ['peri peri french fries',
#   'fresh tuna',
#   'red wine',
#   'pepper',
#   'spaghetti',
#   'fromage blanc',
#   'salmon',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea'],
#  ['cooked spaghetti', 'milk', 'low fat yogurt'],
#  ['baby corn', 'shrimp', 'parmesan cheese', 'soup', 'chocolate', 'brownies'],
#  ['protein bar', 'spaghetti', 'chicken'],
#  ['oat pasta', 'grated cheese', 'vegetables mix', 'nonfat milk', 'green tea'],
#  ['baked salmon',
#   'fresh tuna',
#   'parmesan cheese',
#   'cider',
#   'muffins',
#   'spinach',
#   'honey',
#   'oil'],
#  ['aged champagne', 'cake'],
#  ['white chocolate',
#   'shrimp',
#   'chocolate',
#   'mushroom cream sauce',
#   'candy bars'],
#  ['salted butter', 'candy bars'],
#  ['cooked ham', 'avocado', 'honey'],
#  ['dog pet food', 'shrimp', 'frozen vegetables', 'tomatoes', 'cottage cheese'],
#  ['salted shrimp', 'french fries'],
#  ['mustard hot dogs', 'strawberries'],
#  ['burger mayo', 'ground beef', 'almonds', 'french fries', 'escalope'],
#  ['sliced fromage blanc ', 'grated cheese', 'spaghetti'],
#  ['whole wheat spagetti',
#   'turkey',
#   'mineral water',
#   'butter',
#   'frozen smoothie'],
#  ['cooked spaghetti',
#   'frozen vegetables',
#   'spaghetti',
#   'french fries',
#   'light mayo',
#   'green tea'],
#  ['orange soda',
#   'burgers',
#   'ham',
#   'spaghetti',
#   'whole wheat rice',
#   'eggplant',
#   'chocolate',
#   'cookies',
#   'shallot',
#   'green tea'],
#  ['purple grapes',
#   'grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'blueberries',
#   'light cream',
#   'rice',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'hot dogs'],
#  ['african yams',
#   'burgers',
#   'shrimp',
#   'tomatoes',
#   'bacon',
#   'whole wheat rice',
#   'green tea'],
#  ['blue berry', 'parmesan cheese', 'pancakes'],
#  ['salted toothpaste', 'parmesan cheese', 'cake', 'hot dogs', 'green tea'],
#  ['peri peri french fries',
#   'spaghetti',
#   'milk',
#   'fromage blanc',
#   'ketchup',
#   'chocolate',
#   'babies food'],
#  ['green chili', 'mint'],
#  ['baby eggplant', 'chocolate', 'mint'],
#  ['fried bacon', 'butter', 'french fries', 'salt', 'fresh bread'],
#  ['white strawberries',
#   'chocolate',
#   'french fries',
#   'strawberries',
#   'yogurt cake',
#   'light mayo'],
#  ['protein bar', 'eggs', 'eggplant', 'cookies'],
#  ['pudina chutney', 'yogurt cake'],
#  ['tomato soup',
#   'herb & pepper',
#   'spaghetti',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'honey',
#   'frozen smoothie',
#   'escalope',
#   'pancakes'],
#  ['frozen yogurt', 'frozen vegetables', 'rice', 'chocolate'],
#  ['strawberry babies food',
#   'herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'eggs',
#   'light cream'],
#  ['tomato soup', 'eggs', 'champagne'],
#  ['flavored mayo',
#   'whole wheat pasta',
#   'ground beef',
#   'olive oil',
#   'blueberries',
#   'escalope'],
#  ['white strawberries',
#   'burgers',
#   'red wine',
#   'mineral water',
#   'eggs',
#   'oil',
#   'carrots',
#   'hand protein bar',
#   'tomato juice'],
#  ['lemon black tea',
#   'chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'soup',
#   'olive oil'],
#  ['lemon black tea',
#   'burgers',
#   'shrimp',
#   'mineral water',
#   'chicken',
#   'fromage blanc',
#   'salmon',
#   'eggs',
#   'cake',
#   'frozen smoothie',
#   'strawberries'],
#  ['salted ground beef', 'green tea'],
#  ['water', 'cookies'],
#  ['black beauty zucchini', 'french fries', 'cookies'],
#  ['tomato soup', 'milk', 'butter', 'eggs'],
#  ['strawberry babies food', 'eggs', 'mushroom cream sauce', 'low fat yogurt'],
#  ['black beauty zucchini', 'eggs', 'green tea'],
#  ['multi-purpose essentials', 'mineral water', 'whole wheat rice'],
#  ['glucose energy drink',
#   'shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'mineral water',
#   'whole wheat rice',
#   'cake'],
#  ['dark chocolate', 'whole wheat rice', 'pancakes'],
#  ['whipped cream',
#   'frozen vegetables',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'salmon',
#   'oil',
#   'cooking oil',
#   'frozen smoothie',
#   'cauliflower'],
#  ['pepper powder ', 'green tea'],
#  ['pink shallot', 'fresh tuna', 'eggs', 'escalope', 'strawberries'],
#  ['sliced fromage blanc ',
#   'spaghetti',
#   'soup',
#   'milk',
#   'carrots',
#   'chocolate'],
#  ['smelly cheese',
#   'burgers',
#   'mineral water',
#   'soup',
#   'meatballs',
#   'olive oil'],
#  ['frozen yogurt',
#   'grated cheese',
#   'mineral water',
#   'cooking oil',
#   'french fries',
#   'cookies',
#   'low fat yogurt'],
#  ['chewy candy bars', 'shrimp', 'milk', 'olive oil', 'french fries'],
#  ['blue berry',
#   'frozen vegetables',
#   'mineral water',
#   'pancakes',
#   'cake',
#   'tomato juice'],
#  ['frozon vegetables mix', 'spaghetti', 'milk', 'chicken'],
#  ['white chocolate',
#   'grated cheese',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'cottage cheese',
#   'pancakes'],
#  ['frozen salad', 'ground beef', 'mineral water', 'milk', 'eggs', 'mint'],
#  ['antioxydant sour juice', 'shrimp', 'body spray', 'green tea'],
#  ['oat cereals', 'frozen smoothie'],
#  ['veg burgers',
#   'herb & pepper',
#   'frozen vegetables',
#   'mineral water',
#   'muffins',
#   'cereals'],
#  ['choco chip muffins',
#   'turkey',
#   'tomatoes',
#   'spaghetti',
#   'milk',
#   'cider',
#   'eggs',
#   'honey',
#   'cake',
#   'green tea',
#   'french fries',
#   'brownies',
#   'tomato juice'],
#  ...]

# %% [markdown]
# ## Apriori Algorithm for Market Basket Analysis

# %%
rules = apriori(purchaseList, min_support = 0.001, min_confidence = 0.03, min_lift = 3, min_length = 1)

# %%
# a = 'spaghetti'
b = 'french fries'
sugg = []
final = []
i = 0
for item in rules:
    i+=1
    pair = item[0] 
    items = [x for x in pair]
#     print(items)
    if a in items:
#         print(items)
        sugg = [x for x in items]
        final+=sugg
#         print(final)
final = list(set(final))
print("hi ",final)

# %%
j =0 
data = []
for item in rules:
    print(type(item))
    # First index of the inner list contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    to_print = "Rule: "
    rule = ""

    arrow = " -> "
    for i in range(len(items)):
        to_print += str(items[i]) + arrow
        rule += str(items[i]) + ", "

    print(to_print)
    # Print the support for this association rule
    print("Support: " + str(item[1]))
    # Print the confidence and lift for this association rule
    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    data.append([rule,item[1],item[2][0][2],item[2][0][3]])
    print("=====================================")
    j+=1
print("\n\n", j)
print(data)
# Out:
# <class 'apyori.RelationRecord'>
# Rule: almonds -> fresh tuna ->
# Support: 0.001599786695107319
# Confidence: 0.0784313725490196
# Lift: 3.5228366795820123
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: cereals -> antioxydant juice ->
# Support: 0.0014664711371817091
# Confidence: 0.16417910447761194
# Lift: 6.38086768231382
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: melons -> avocado ->
# Support: 0.0013331555792560992
# Confidence: 0.04
# Lift: 3.333777777777778
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: toothpaste -> avocado ->
# Support: 0.0010665244634048793
# Confidence: 0.031999999999999994
# Lift: 3.934950819672131
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: yams -> avocado ->
# Support: 0.0011998400213304892
# Confidence: 0.036
# Lift: 3.1399534883720928
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: barbecue sauce -> bacon ->
# Support: 0.0011998400213304892
# Confidence: 0.13846153846153847
# Lift: 12.822222222222223
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: cooking oil -> bacon ->
# Support: 0.001599786695107319
# Confidence: 0.18461538461538463
# Lift: 3.6156657963446475
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: red wine -> bacon ->
# Support: 0.0010665244634048793
# Confidence: 0.12307692307692307
# Lift: 4.375355450236967
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: butter -> barbecue sauce ->
# Support: 0.0011998400213304892
# Confidence: 0.1111111111111111
# Lift: 3.687807276302851
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: turkey -> barbecue sauce ->
# Support: 0.0025329956005865884
# Confidence: 0.2345679012345679
# Lift: 3.751585985416831
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: black tea -> french wine ->
# Support: 0.0013331555792560992
# Confidence: 0.09345794392523364
# Lift: 4.1480948957584465
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: black tea -> pepper ->
# Support: 0.0011998400213304892
# Confidence: 0.08411214953271028
# Lift: 3.170478561029446
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: blueberries -> grated cheese ->
# Support: 0.0014664711371817091
# Confidence: 0.15942028985507248
# Lift: 3.0427775933915995
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: blueberries -> light cream ->
# Support: 0.0010665244634048793
# Confidence: 0.11594202898550723
# Lift: 7.433172302737519
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: body spray -> energy drink ->
# Support: 0.0010665244634048793
# Confidence: 0.09302325581395349
# Lift: 3.4888372093023254
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: body spray -> soup ->
# Support: 0.0018664178109585388
# Confidence: 0.16279069767441862
# Lift: 3.221881327851752
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: whole wheat pasta -> body spray ->
# Support: 0.0010665244634048793
# Confidence: 0.09302325581395349
# Lift: 3.157318741450068
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: cottage cheese -> brownies ->
# Support: 0.0034662045060658577
# Confidence: 0.10276679841897232
# Lift: 3.225329518580382
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: chicken -> bug spray ->
# Support: 0.001599786695107319
# Confidence: 0.18461538461538463
# Lift: 3.0773333333333337
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: chicken -> burger sauce ->
# Support: 0.001599786695107319
# Confidence: 0.2727272727272727
# Lift: 4.546060606060606
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: magazines -> butter ->
# Support: 0.0010665244634048793
# Confidence: 0.035398230088495575
# Lift: 3.2380746816317725
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: carrots -> ham ->
# Support: 0.001599786695107319
# Confidence: 0.10434782608695653
# Lift: 3.9332313742626175
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: carrots -> oil ->
# Support: 0.001599786695107319
# Confidence: 0.10434782608695653
# Lift: 4.524352852475497
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: carrots -> salmon ->
# Support: 0.001999733368884149
# Confidence: 0.13043478260869568
# Lift: 3.0670573804007093
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: cereals -> fromage blanc ->
# Support: 0.0010665244634048793
# Confidence: 0.04145077720207254
# Lift: 3.048257645026923
# =====================================
# <class 'apyori.RelationRecord'>
# Rule: cereals -> gums ->
# Support: 0.0011998400213304892
# Confidence: 0.046632124352331605
# Lift: 3.4632432155132613
# =====================================
# <class 'apyori.RelationRecord'>
# Rule:
728969470737, 0.07555555555555556, 4.843950617283951], ['chicken, magazines, ', 0.001999733368884149, 0.03333333333333334, 3.0491869918699197], ['whole weat flour, chicken, ', 0.0017331022530329288, 0.1857142857142857, 3.0956507936507935], ['chocolate bread, red wine, ', 0.0010665244634048793, 0.25, 8.887440758293838], ['clothes accessories, herb & pepper, ', 0.0013331555792560992, 0.15873015873015872, 3.2092585461857697], ['shallot, cookies, ', 0.001999733368884149, 0.25862068965517243, 3.2171041344999143], ['cooking oil, light cream, ', 0.0027996267164378083, 0.054830287206266315, 3.5152306353350737], ['toothpaste, cooking oil, ', 0.0018664178109585388, 0.03655352480417754, 4.49488507469075], ['cooking oil, zucchini, ', 0.0014664711371817091, 0.15492957746478872, 3.034273526275144], ['corn, tomatoes, ', 0.0010665244634048793, 0.2222222222222222, 3.249296079705436], ['salmon, dessert wine, ', 0.0010665244634048793, 0.2424242424242424, 5.700389474684145], ['rice, eggplant, ', 0.0010665244634048793, 0.0808080808080808, 4.298875277598682], ['escalope, mushroom cream sauce, ', 0.005732568990801226, 0.0722689075630252, 3.7908326967150496], ['escalope, pasta, ', 0.005865884548726837, 0.07394957983193277, 4.700811850163794], ['escalope, shallot, ', 0.0018664178109585388, 0.2413793103448276, 3.043002028397566], ['extra dark chocolate, light cream, ', 0.001599786695107319, 0.13333333333333336, 8.54814814814815], ['olive oil, extra dark cho ...

# %% [markdown]
# ## Most Repeated Purchases with count

# %%
SCL = pd.DataFrame(data, columns=['Accociation', 'Support', 'Confidence', 'Lift'])
SCL.head(15)
# Out:
#                      Accociation   Support  Confidence       Lift
# 0          almonds, fresh tuna,   0.001600    0.078431   3.522837
# 1   cereals, antioxydant juice,   0.001466    0.164179   6.380868
# 2              melons, avocado,   0.001333    0.040000   3.333778
# 3          toothpaste, avocado,   0.001067    0.032000   3.934951
# 4                yams, avocado,   0.001200    0.036000   3.139953
# 5        barbecue sauce, bacon,   0.001200    0.138462  12.822222
# 6           cooking oil, bacon,   0.001600    0.184615   3.615666
# 7              red wine, bacon,   0.001067    0.123077   4.375355
# 8       butter, barbecue sauce,   0.001200    0.111111   3.687807
# 9       turkey, barbecue sauce,   0.002533    0.234568   3.751586
# 10      black tea, french wine,   0.001333    0.093458   4.148095
# 11           black tea, pepper,   0.001200    0.084112   3.170479
# 12  blueberries, grated cheese,   0.001466    0.159420   3.042778
# 13    blueberries, light cream,   0.001067    0.115942   7.433172
# 14    body spray, energy drink,   0.001067    0.093023   3.488837

# %%
import dataframe_image as dfi
dfi.export(SCL, 'SCL.png', max_rows=10)

# %%
scl_desc = SCL.describe()
dfi.export(scl_desc, 'scl_desc.png', max_rows=10)

# %%
items = purchases.values.ravel()
items

# %%
itemCount = collections.Counter(items)
itemCount

# %%
itemsDF = pd.DataFrame(itemCount.items())
itemsDF

# %%
itemsDF = itemsDF.rename(columns={0:'Item Name',1:'Total'})
itemsDF

# %%
itemsDF.sort_values(by = "Total", ascending = False)[1:]

# %% [markdown]
# From here, it is evident that Mineral Water, Eggs, Spaghetti are the most repaeted items.
